# %% [markdown]
# # **1. Legendre Features using OLS**

# %% [markdown]
# ## **1.1 First experiment $(2x + cos(25x))$**

# %% [markdown]
# We are going to approximate an objective function using Legendre polynomial regression, following "arXiv:2303.14151" and using OLS (Ordinary Least Squares).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Objective function

# %% [markdown]
# First, we define the function we want to approximate. In our case, we will work with the following function:
#
# $$
#   y(x) = 2x + cos(25x)
# $$

# %%
def objective_function1(x):
  '''
  Objective function (unknown) we want to approximate using training data. In this
  case we use y(x) = 2x + cos(25x) as objective function.

  '''
  # We use y(x) = 2x + cos(25x) as objective function, following "arXiv:2303.14151"
  return np.float64(2*x+ np.cos(25*x))

# %% [markdown]
# Next, let's plot the function we want to approximate in the interval $[-1, 1]$. To do this, we define a series of equispaced points in that interval to which we apply the function (these points will be our test data).

# %%
def plot_objective_function(objective_function, function, lower_bound=-1.0, higher_bound=1.0, num_points=1000):
  '''
  Function to plot the given objective function over the interval [lower_bound, higher_bound].

  '''
  # Following "arXiv:2303.14151" we wish to predict objective function from x ∈ [-1, 1]
  # In order to plot the objective function we create 1000 points equispaced on the interval and we apply the objective function to them
  X_test = np.linspace(lower_bound, higher_bound, num=num_points)
  y_test = objective_function(X_test)

  # We need to normalize x to the range [-1, 1] in order to use Legendre polynomials
  X_test = 2 * (X_test - lower_bound) / (higher_bound - lower_bound) - 1

  # Now we plot the objective function in the interval [-1, 1]
  sns.lineplot(x=X_test, y=y_test, label="Objective function")
  plt.xlabel("x")
  plt.ylabel("y")
  plt.title(f"Function to approximate: {function}", fontweight='bold')
  plt.legend()
  plt.show()

# %%
plot_objective_function(objective_function1, "$2x + cos(25x)$")

# %% [markdown]
# To create our training set, we define the functions **"generate_training_data()"** and **"generate_uniformly_distributed_training_data()"** to obtain a predetermined number of training points.

# %%
def generate_training_data(low, high, num_samples, objective_function):
  '''
  The function is given two limits: low and high and a desired number of samples
  to create samples that are uniformly distributed over the interval [low, high)
  and to which the objective function is applied.

  Example of use:
  X_train, y_train = generate_training_data(-1, 1, 10, x**2)

  '''
  # We use "np.random.uniform" to create samples that are uniformly distributed over the interval [low, high)
  X = np.random.uniform(low=low, high=high, size=num_samples)
  # We apply the objective function to the samples
  y = objective_function(X)
  return X, y

# %%
def generate_uniformly_distributed_training_data(low, high, num_samples, objective_function, num_intervals = 5):
  '''
  Generates uniformly distributed data over a number of intervals within the range [low, high).

  The function divides the interval [low, high) into a fixed number of sub-intervals and
  generates uniformly distributed samples within each sub-interval. Then, it applies
  the objective function to the generated samples.

  Example of use:
  X_train, y_train = generate_uniformly_distributed_training_data(-1, 1, 10, x**2)

  '''
  samples_per_interval = num_samples // num_intervals

  X = []
  for i in range(num_intervals):
      sub_low = low + i * (high - low) / num_intervals
      sub_high = low + (i + 1) * (high - low) / num_intervals
      X.extend(np.random.uniform(low=sub_low, high=sub_high, size=samples_per_interval))

  X = np.array(X)
  # Normalize X in the interval [-1, 1] (for Legendre approximation)
  X_normalized = 2 * (X - low) / (high - low) - 1
  y = objective_function(X)
  return X_normalized, y

# %% [markdown]
# In addition, we define a function **"plot_objective_function_and_training_data()"** to plot both the training points and the objective function.

# %%
def plot_objective_function_and_training_data(X_train, y_train, X_test, y_test):
  '''
  Function to plot the training data (X_train, y_train) together with the
  objective function (X_test, y_test).

  '''
  # To make sure we are working with 1D arrays
  X_train = X_train.reshape(-1)
  X_test = X_test.reshape(-1)

  # We plot the figure containing the objective function and the training data
  plt.figure()
  # Objective function
  sns.lineplot(x=X_test, y=y_test, label="Objective function")
  # Training data
  sns.scatterplot(x=X_train, y=y_train, s=50, color="black", label="Training data")
  plt.xlabel("x")
  plt.ylabel("y")
  plt.legend(loc="upper left")
  plt.show()

# %% [markdown]
# ### Training data

# %% [markdown]
# We start by generating our training data (10 samples) and plotting it together with the objective function.

# %%
# Here we generate the training data and we plot them together with the objective function
lower_bound, higher_bound = -1.0, 1.0
X_test = np.linspace(lower_bound, higher_bound, num=1000)
y_test = objective_function1(X_test)
n_samples = 10
X_train, y_train = generate_training_data(lower_bound, higher_bound, n_samples, objective_function1)
plot_objective_function_and_training_data(X_train, y_train, X_test, y_test)

# %% [markdown]
# ### Legendre approximation

# %% [markdown]
# We define the function **"fit_legendre_polynomial_regression()"** to fit the Legendre polynomials to the samples we have.

# %%
from scipy.special import eval_legendre

def fit_legendre_polynomial_regression(degree, X_train, y_train, X_test):
  '''
  Function to perform the polynomial approximation (using Legendre polynomials).
  We need the desired degree for the approximation, the training data and the test data.

  Recall that the Legendre approximation is based on the following polynomial:
  f(x) ≈ a_0*P_0(x) + a_1*P_1(x) + ... + a_n*P_n(x) where P_i(x) is the i-th Legendre polynomial (https://mathworld.wolfram.com/LegendrePolynomial.html).

  Example of use:
  X_train_poly, y_train_pred, y_test_pred = fit_legendre_polynomial_regression(1, X_train, y_train, X_test)

  '''
  # In order to approximate the i-th Legendre polynomial, we need all the P_j(x) {j ∈ [1, n]} Legendre polynomials, so we create an array with all these necessary indices
  # "np.arange" is returning an array consisting of [0, degree-1] so we need to sum "1" in every index
  degrees = np.arange(degree) + 1

  # We need to work with 2D arrays to use "eval_legendre" function
  X_train = X_train.reshape(-1, 1)
  X_test = X_test.reshape(-1, 1)

  # We use "eval_legendre" function to evaluate the d-th Legendre polynomial at each training point in X_train (we need all the P_j(x) {j ∈ [1, n]} Legendre polynomials to approximate)
  X_train_poly = np.column_stack([eval_legendre(d, X_train) for d in degrees])
  # We use "eval_legendre" function to evaluate the d-th Legendre polynomial at each test point in X_test
  X_test_poly = np.column_stack([eval_legendre(d, X_test) for d in degrees])

  # In order to calculate w (vector of weights/coefficients for the regression) we need (check slide 15/23 from https://work.caltech.edu/slides/slides03.pdf):
    # 1. We need to compute the pseudo-inverse of X_train_poly (which contains the Legendre features of the polynomial regression)
    # 2. We need to multiply the pseudo-inverse by the y_train data
  w = np.matmul(np.linalg.pinv(X_train_poly), y_train)

  # Here we calculate the predictions of the training and test data with the vector w of weights
  y_train_pred = np.matmul(X_train_poly, w)
  y_test_pred = np.matmul(X_test_poly, w)

  return X_train_poly, y_train_pred, y_test_pred

# %% [markdown]
# We also define a function to plot the approximation made by the Legendre polynomials.

# %%
def plot_fitting_approximation(X_train, y_train, X_test, y_test, y_test_pred, degree, y_lower, y_upper):
  '''
  Function to plot the training data (X_train, y_train) together with the
  objective function (X_test, y_test) and the fitted function (y_test_pred) for
  the specified number of params (degree) along the y-axis [y_lower, y_upper].

  '''
  # To make sure we are working with 1D arrays
  X_train = X_train.reshape(-1)
  X_test = X_test.reshape(-1)

  # We plot the figure containing the objective function, the training data and the fitted function
  plt.figure()
  sns.lineplot(x=X_test, y=y_test, label="Objective function")
  sns.lineplot(x=X_test, y=y_test_pred, label=f"Fitted function - {degree} params")
  sns.scatterplot(x=X_train, y=y_train, s=50, color="black", label="Training data")
  plt.xlabel("x")
  plt.ylabel("y")
  plt.ylim(y_lower, y_upper)
  plt.legend(loc="upper left")
  plt.show()

# %% [markdown]
# ### Training the model

# %% [markdown]
# Now, we will approximate the training data using Legendre's polynomial approximation for different degrees of freedom (degrees of the polynomial to be fitted) and calculate both training and test loss.

# %%
output = []

from sklearn.metrics import mean_squared_error

# Number of params we want to use for the approximation (we use [1, 200] params following "arXiv:2303.14151")
degrees = list(range(1, 201))

# For each degree in [1, 200] we calculate the fitted function and see how it fits the objective function by using MSE in training and test.
for degree in degrees:
  X_train_poly, y_train_pred, y_test_pred = fit_legendre_polynomial_regression(degree, X_train, y_train, X_test)

  # We calculate the MSE for the training and test data
  train_error = mean_squared_error(y_train, y_train_pred)
  test_error = mean_squared_error(y_test, y_test_pred)

  # We print the degree and both the MSE in training and the MSE in test for that approximation
  print(f"# of parameters = {degree}, train_error = {train_error:.4f}, test_error = {test_error:.4f}")

  # We save all the results so we can use them lately
  output.append({"# of parameters": degree, "X_train_poly": X_train_poly, "train_error": train_error, "test_error": test_error, "y_test_pred": y_test_pred})

# We convert the output into a pandas dataframe
output_df = pd.DataFrame(output)
# Out:
# # of parameters = 1, train_loss = 0.2546, test_loss = 0.4990
# # of parameters = 2, train_loss = 0.2546, test_loss = 0.4990
# # of parameters = 3, train_loss = 0.2356, test_loss = 0.5270
# # of parameters = 4, train_loss = 0.2303, test_loss = 0.5173
# # of parameters = 5, train_loss = 0.1841, test_loss = 0.7673
# # of parameters = 6, train_loss = 0.0915, test_loss = 0.8475
# # of parameters = 7, train_loss = 0.0757, test_loss = 1.0521
# # of parameters = 8, train_loss = 0.0693, test_loss = 1.2024
# # of parameters = 9, train_loss = 0.0048, test_loss = 10.5021
# # of parameters = 10, train_loss = 0.0000, test_loss = 4.0892
# # of parameters = 11, train_loss = 0.0000, test_loss = 3.9164
# # of parameters = 12, train_loss = 0.0000, test_loss = 3.8855
# # of parameters = 13, train_loss = 0.0000, test_loss = 3.5689
# # of parameters = 14, train_loss = 0.0000, test_loss = 3.0333
# # of parameters = 15, train_loss = 0.0000, test_loss = 1.9970
# # of parameters = 16, train_loss = 0.0000, test_loss = 1.4689
# # of parameters = 17, train_loss = 0.0000, test_loss = 1.4820
# # of parameters = 18, train_loss = 0.0000, test_loss = 1.1673
# # of parameters = 19, train_loss = 0.0000, test_loss = 0.9658
# # of parameters = 20, train_loss = 0.0000, test_loss = 0.9163
# # of parameters = 21, train_loss = 0.0000, test_loss = 0.8040
# # of parameters = 22, train_loss = 0.0000, test_loss = 0.6913
# # of parameters = 23, train_loss = 0.0000, test_loss = 0.6876
# # of parameters = 24, train_loss = 0.0000, test_loss = 0.6279
# # of parameters = 25, train_loss = 0.0000, test_loss = 0.6323
# # of parameters = 26, train_loss = 0.0000, test_loss = 0.5881
# # of parameters = 27, train_loss = 0.0000, test_loss = 0.5855
# # of parameters = 28, train_loss = 0.0000, test_loss = 0.5639
# # of parameters = 29, train_loss = 0.0000, test_loss = 0.5691
# # of parameters = 30, train_loss = 0.0000, test_loss = 0.5725
# # of parameters = 31, train_loss = 0.0000, test_loss = 0.5774
# # of parameters = 32, train_loss = 0.0000, test_loss = 0.5735
# # of parameters = 33, train_loss = 0.0000, test_loss = 0.5729
# # of parameters = 34, train_loss = 0.0000, test_loss = 0.5720
# # of parameters = 35, train_loss = 0.0000, test_loss = 0.5727
# # of parameters = 36, train_loss = 0.0000, test_loss = 0.5754
# # of parameters = 37, train_loss = 0.0000, test_loss = 0.5735
# # of parameters = 38, train_loss = 0.0000, test_loss = 0.5672
# # of parameters = 39, train_loss = 0.0000, test_loss = 0.5742
# # of parameters = 40, train_loss = 0.0000, test_loss = 0.5814
# # of parameters = 41, train_loss = 0.0000, test_loss = 0.5745
# # of parameters = 42, train_loss = 0.0000, test_loss = 0.5763
# # of parameters = 43, train_loss = 0.0000, test_loss = 0.5752
# # of parameters = 44, train_loss = 0.0000, test_loss = 0.5792
# # of parameters = 45, train_loss = 0.0000, test_loss = 0.5797
# # of parameters = 46, train_loss = 0.0000, test_loss = 0.5798
# # of parameters = 47, train_loss = 0.0000, test_loss = 0.5793
# # of parameters = 48, train_loss = 0.0000, test_loss = 0.5792
# # of parameters = 49, train_loss = 0.0000, test_loss = 0.5786
# # of parameters = 50, train_loss = 0.0000, test_loss = 0.5787
# # of parameters = 51, train_loss = 0.0000, test_loss = 0.5844
# # of parameters = 52, train_loss = 0.0000, test_loss = 0.5818
# # of parameters = 53, train_loss = 0.0000, test_loss = 0.5819
# # of parameters = 54, train_loss = 0.0000, test_loss = 0.5814
# # of parameters = 55, train_loss = 0.0000, test_loss = 0.5813
# # of parameters = 56, train_loss = 0.0000, test_loss = 0.5835
# # of parameters = 57, train_loss = 0.0000, test_loss = 0.5846
# # of parameters = 58, train_loss = 0.0000, test_loss = 0.5771
# # of parameters = 59, train_loss = 0.0000, test_loss = 0.5784
# # of parameters = 60, train_loss = 0.0000, test_loss = 0.5816
# # of parameters = 61, train_loss = 0.0000, test_loss = 0.5810
# # of parameters = 62, train_loss = 0.0000, test_loss = 0.5810
# # of parameters = 63, train_loss = 0.0000, test_loss = 0.5795
# # of parameters = 64, train_loss = 0.0000, test_loss = 0.5824
# # of parameters = 65, train_loss = 0.0000, test_loss = 0.5831
# # of parameters = 66, train_loss = 0.0000, test_loss = 0.5836
# # of parameters = 67, train_loss = 0.0000, test_loss = 0.5845
# # of parameters = 68, train_loss = 0.0000, test_loss = 0.5854
# # of parameters = 69, train_loss = 0.0000, test_loss = 0.5864
# # of parameters = 70, train_loss = 0.0000, test_loss = 0.5873
# # of parameters = 71, train_loss = 0.0000, test_loss = 0.5910
# # of parameters = 72, train_loss = 0.0000, test_loss = 0.5913
# # of parameters = 73, train_loss = 0.0000, test_loss = 0.5915
# # of parameters = 74, train_loss = 0.0000, test_loss = 0.5908
# # of parameters = 75, train_loss = 0.0000, test_loss = 0.5909
# # of parameters = 76, train_loss = 0.0000, test_loss = 0.5915
# # of parameters = 77, train_loss = 0.0000, test_loss = 0.5923
# # of parameters = 78, train_loss = 0.0000, test_loss = 0.5885
# # of parameters = 79, train_loss = 0.0000, test_loss = 0.5889
# # of parameters = 80, train_loss = 0.0000, test_loss = 0.5920
# # of parameters = 81, train_loss = 0.0000, test_loss = 0.5934
# # of parameters = 82, train_loss = 0.0000, test_loss = 0.5940
# # of parameters = 83, train_loss = 0.0000, test_loss = 0.5936
# # of parameters = 84, train_loss = 0.0000, test_loss = 0.5968
# # of parameters = 85, train_loss = 0.0000, test_loss = 0.5970
# # of parameters = 86, train_loss = 0.0000, test_loss = 0.5969
# # of parameters = 87, train_loss = 0.0000, test_loss = 0.5968
# # of parameters = 88, train_loss = 0.0000, test_loss = 0.5966
# # of parameters = 89, train_loss = 0.0000, test_loss = 0.5997
# # of parameters = 90, train_loss = 0.0000, test_loss = 0.6001
# # of parameters = 91, train_loss = 0.0000, test_loss = 0.6006
# # of parameters = 92, train_loss = 0.0000, test_loss = 0.6007
# # of parameters = 93, train_loss = 0.0000, test_loss = 0.6022
# # of parameters = 94, train_loss = 0.0000, test_loss = 0.6011
# # of parameters = 95, train_loss = 0.0000, test_loss = 0.6008
# # of parameters = 96, train_loss = 0.0000, test_loss = 0.6011
# # of parameters = 97, train_loss = 0.0000, test_loss = 0.6011
# # of parameters = 98, train_loss = 0.0000, test_loss = 0.6009
# # of parameters = 99, train_loss = 0.0000, test_loss = 0.6028
# # of parameters = 100, train_loss = 0.0000, test_loss = 0.6038
# # of parameters = 101, train_loss = 0.0000, test_loss = 0.6034
# # of parameters = 102, train_loss = 0.0000, test_loss = 0.6038
# # of parameters = 103, train_loss = 0.0000, test_loss = 0.6037
# # of parameters = 104, train_loss = 0.0000, test_loss = 0.6053
# # of parameters = 105, train_loss = 0.0000, test_loss = 0.6053
# # of parameters = 106, train_loss = 0.0000, test_loss = 0.6056
# # of parameters = 107, train_loss = 0.0000, test_loss = 0.6056
# # of parameters = 108, train_loss = 0.0000, test_loss = 0.6064
# # of parameters = 109, train_loss = 0.0000, test_loss = 0.6102
# # of parameters = 110, train_loss = 0.0000, test_loss = 0.6106
# # of parameters = 111, train_loss = 0.0000, test_loss = 0.6106
# # of parameters = 112, train_loss = 0.0000, test_loss = 0.6104
# # of parameters = 113, train_loss = 0.0000, test_loss = 0.6139
# # of parameters = 114, train_loss = 0.0000, test_loss = 0.6139
# # of parameters = 115, train_loss = 0.0000, test_loss = 0.6134
# # of parameters = 116, train_loss = 0.0000, test_loss = 0.6131
# # of parameters = 117, train_loss = 0.0000, test_loss = 0.6127
# # of parameters = 118, train_loss = 0.0000, test_loss = 0.6131
# # of parameters = 119, train_loss = 0.0000, test_loss = 0.6153
# # of parameters = 120, train_loss = 0.0000, test_loss = 0.6151
# # of parameters = 121, train_loss = 0.0000, test_loss = 0.6140
# # of parameters = 122, train_loss = 0.0000, test_loss = 0.6147
# # of parameters = 123, train_loss = 0.0000, test_loss = 0.6148
# # of parameters = 124, train_loss = 0.0000, test_loss = 0.6146
# # of parameters = 125, train_loss = 0.0000, test_loss = 0.6148
# # of parameters = 126, train_loss = 0.0000, test_loss = 0.6156
# # of parameters = 127, train_loss = 0.0000, test_loss = 0.6156
# # of parameters = 128, train_loss = 0.0000, test_loss = 0.6163
# # of parameters = 129, train_loss = 0.0000, test_loss = 0.6177
# # of parameters = 130, train_loss = 0.0000, test_loss = 0.6176
# # of parameters = 131, train_loss = 0.0000, test_loss = 0.6176
# # of parameters = 132, train_loss = 0.0000, test_loss = 0.6167
# # of parameters = 133, train_loss = 0.0000, test_loss = 0.6181
# # of parameters = 134, train_loss = 0.0000, test_loss = 0.6186
# # of parameters = 135, train_loss = 0.0000, test_loss = 0.6183
# # of parameters = 136, train_loss = 0.0000, test_loss = 0.6182
# # of parameters = 137, train_loss = 0.0000, test_loss = 0.6185
# # of parameters = 138, train_loss = 0.0000, test_loss = 0.6185
# # of parameters = 139, train_loss = 0.0000, test_loss = 0.6197
# # of parameters = 140, train_loss = 0.0000, test_loss = 0.6196
# # of parameters = 141, train_loss = 0.0000, test_loss = 0.6189
# # of parameters = 142, train_loss = 0.0000, test_loss = 0.6193
# # of parameters = 143, train_loss = 0.0000, test_loss = 0.6191
# # of parameters = 144, train_loss = 0.0000, test_loss = 0.6191
# # of parameters = 145, train_loss = 0.0000, test_loss = 0.6192
# # of parameters = 146, train_loss = 0.0000, test_loss = 0.6201
# # of parameters = 147, train_loss = 0.0000, test_loss = 0.6200
# # of parameters = 148, train_loss = 0.0000, test_loss = 0.6204
# # of parameters = 149, train_loss = 0.0000, test_loss = 0.6206
# # of parameters = 150, train_loss = 0.0000, test_loss = 0.6208
# # of parameters = 151, train_loss = 0.0000, test_loss = 0.6213
# # of parameters = 152, train_loss = 0.0000, test_loss = 0.6214
# # of parameters = 153, train_loss = 0.0000, test_loss = 0.6214
# # of parameters = 154, train_loss = 0.0000, test_loss = 0.6223
# # of parameters = 155, train_loss = 0.0000, test_loss = 0.6232
# # of parameters = 156, train_loss = 0.0000, test_loss = 0.6236
# # of parameters = 157, train_loss = 0.0000, test_loss = 0.6241
# # of parameters = 158, train_loss = 0.0000, test_loss = 0.6235
# # of parameters = 159, train_loss = 0.0000, test_loss = 0.6233
# # of parameters = 160, train_loss = 0.0000, test_loss = 0.6229
# # of parameters = 161, train_loss = 0.0000, test_loss = 0.6226
# # of parameters = 162, train_loss = 0.0000, test_loss = 0.6227
# # of parameters = 163, train_loss = 0.0000, test_loss = 0.6230
# # of parameters = 164, train_loss = 0.0000, test_loss = 0.6232
# # of parameters = 165, train_loss = 0.0000, test_loss = 0.6232
# # of parameters = 166, train_loss = 0.0000, test_loss = 0.6233
# # of parameters = 167, train_loss = 0.0000, test_loss = 0.6234
# # of parameters = 168, train_loss = 0.0000, test_loss = 0.6235
# # of parameters = 169, train_loss = 0.0000, test_loss = 0.6234
# # of parameters = 170, train_loss = 0.0000, test_loss = 0.6231
# # of parameters = 171, train_loss = 0.0000, test_loss = 0.6232
# # of parameters = 172, train_loss = 0.0000, test_loss = 0.6243
# # of parameters = 173, train_loss = 0.0000, test_loss = 0.6241
# # of parameters = 174, train_loss = 0.0000, test_loss = 0.6243
# # of parameters = 175, train_loss = 0.0000, test_loss = 0.6247
# # of parameters = 176, train_loss = 0.0000, test_loss = 0.6256
# # of parameters = 177, train_loss = 0.0000, test_loss = 0.6261
# # of parameters = 178, train_loss = 0.0000, test_loss = 0.6260
# # of parameters = 179, train_loss = 0.0000, test_loss = 0.6260
# # of parameters = 180, train_loss = 0.0000, test_loss = 0.6258
# # of parameters = 181, train_loss = 0.0000, test_loss = 0.6258
# # of parameters = 182, train_loss = 0.0000, test_loss = 0.6269
# # of parameters = 183, train_loss = 0.0000, test_loss = 0.6276
# # of parameters = 184, train_loss = 0.0000, test_loss = 0.6278
# # of parameters = 185, train_loss = 0.0000, test_loss = 0.6278
# # of parameters = 186, train_loss = 0.0000, test_loss = 0.6278
# # of parameters = 187, train_loss = 0.0000, test_loss = 0.6283
# # of parameters = 188, train_loss = 0.0000, test_loss = 0.6282
# # of parameters = 189, train_loss = 0.0000, test_loss = 0.6283
# # of parameters = 190, train_loss = 0.0000, test_loss = 0.6277
# # of parameters = 191, train_loss = 0.0000, test_loss = 0.6282
# # of parameters = 192, train_loss = 0.0000, test_loss = 0.6303
# # of parameters = 193, train_loss = 0.0000, test_loss = 0.6306
# # of parameters = 194, train_loss = 0.0000, test_loss = 0.6307
# # of parameters = 195, train_loss = 0.0000, test_loss = 0.6305
# # of parameters = 196, train_loss = 0.0000, test_loss = 0.6321
# # of parameters = 197, train_loss = 0.0000, test_loss = 0.6323
# # of parameters = 198, train_loss = 0.0000, test_loss = 0.6322
# # of parameters = 199, train_loss = 0.0000, test_loss = 0.6320
# # of parameters = 200, train_loss = 0.0000, test_loss = 0.6320

# %% [markdown]
# We can check the approximations made for each degree of the Legendre polynomial.

# %%
degree = 1
print("Training data values: ", X_train)
print()
# We know that P_1(x) = x, so the values for X_train_poly using degree = 1 must be the same values as X_train
print("X_train_poly values: ", output_df.loc[degree-1, 'X_train_poly'].reshape(-1))
# Out:
# Training data values:  [-0.78929869 -0.94228507 -0.58345553 -0.03981376 -0.32667777  0.66679272
#   0.3126241   0.81955621  0.78291738  0.27533444]
#
# X_train_poly values:  [-0.78929869 -0.94228507 -0.58345553 -0.03981376 -0.32667777  0.66679272
#   0.3126241   0.81955621  0.78291738  0.27533444]

# %% [markdown]
# ### Some approximations

# %% [markdown]
# We now plot some of the approximations obtained by the Legendre polynomials (we note that the higher the degree used for the approximation the smoother the fitted function).

# %%
# We plot the objective function, fitted function and training data
y_lower, y_upper = -3, 3
degree = 1
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 10
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 100
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 200
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)

# %% [markdown]
# ### Double descent phenomenon

# %% [markdown]
# Finally, we plot both the training error curve and the test error curve. We observe how the double descent phenomenon occurs and where the peak of the test error is close to the interpolation threshold (≈ number of training samples when there is no label noise).

# %%
def plot_double_descent(output_df, samples, function, legendre = True, ylim_bottom = 0.001):
  '''
  Function to plot the double descent phenomenon, using the MSE error metric
  (We use the output dataframe to recover all information we need to plot). If
  legendre = True then legendre approximation is performed.

  '''
  plt.figure(figsize=(12, 8))
  # Test loss / Test error
  sns.lineplot(
      data=output_df,
      x="# of parameters",
      y="test_error",
      label="Test",
      marker="D",
  )
  # Train loss / Train error
  sns.lineplot(
      data=output_df,
      x="# of parameters",
      y="train_error",
      label="Train",
      marker="D",
  )
  plt.ylabel("Mean Squared Error (MSE)")
  plt.xlabel("# of Parameters")

  if ylim_bottom > 0:
    plt.ylim(ylim_bottom)

  plt.xscale("log")
  plt.yscale("log")
  title_prefix = "Legendre" if legendre else ""
  plt.title(f"{title_prefix} Polynomial Regression (Train/Test Error by number of parameters (degrees)) for {function}", fontweight='bold')
  # Interpolation threshold ≈ number of training data samples used
  plt.axvline(x=samples, color="black", linestyle="--", label="Interpolation threshold")
  plt.legend(loc="upper right")

  plt.tight_layout()
  plt.show()

# %%
plot_double_descent(output_df, n_samples, "$2x + cos(25x)$")

# %% [markdown]
# \

# %% [markdown]
# ## **1.2 Second experiment $(x^2 + cos(25x))$**

# %% [markdown]
# We are now going to change our objective function to observe the behavior of double descent on different types of functions. To do this, we will change the function that governs the trend of the objective function ($2x$) and keep the function that injects “noise” into the objective function ($cos(25x)$).

# %%
def objective_function2(x):
  '''
  Objective function (unknown) we want to approximate using training data. In this
  case we use y(x) = x**2 + cos(25x) as objective function

  '''
  return np.float64(x**2 + np.cos(25*x))

# %% [markdown]
# The new objective function changes the trend function ($2x$) from linear to quadratic ($x^2$).

# %%
plot_objective_function(objective_function2, "$x^2 + cos(25x)$")

# %%
# Here we generate the training data and we plot them together with the objective function
lower_bound, higher_bound = -1.0, 1.0
X_test = np.linspace(lower_bound, higher_bound, num=1000)
y_test = objective_function2(X_test)
n_samples = 10
X_train, y_train = generate_uniformly_distributed_training_data(lower_bound, higher_bound, n_samples, objective_function2)
plot_objective_function_and_training_data(X_train, y_train, X_test, y_test)

# %% [markdown]
# In this case we use a new function to generate the training samples (***generate_uniformly_distributed_training_data()***), so that they are equispaced over the interval $[-1, 1]$, so that there are not many training samples together which makes the approximation more difficult overall.

# %%
output = []

from sklearn.metrics import mean_squared_error

# Number of params we want to use for the approximation
degrees = list(range(1, 201))

# For each degree in [1, 200] we calculate the fitted function and see how it fits the objective function by using MSE in training and test.
for degree in degrees:
  X_train_poly, y_train_pred, y_test_pred = fit_legendre_polynomial_regression(degree, X_train, y_train, X_test)

  # We calculate the MSE for the training and test data
  train_error = mean_squared_error(y_train, y_train_pred)
  test_error = mean_squared_error(y_test, y_test_pred)

  # We print the degree and both the MSE in training and the MSE in test for that approximation
  print(f"# of parameters = {degree}, train_error = {train_error:.4f}, test_error = {test_error:.4f}")

  # We save all the results so we can use them lately
  output.append({"# of parameters": degree, "X_train_poly": X_train_poly, "train_error": train_error, "test_error": test_error, "y_test_pred": y_test_pred})

# We convert the output into a pandas dataframe
output_df = pd.DataFrame(output)
# Out:
# # of parameters = 1, train_loss = 0.5241, test_loss = 0.7441
# # of parameters = 2, train_loss = 0.4828, test_loss = 0.6599
# # of parameters = 3, train_loss = 0.4126, test_loss = 0.7102
# # of parameters = 4, train_loss = 0.2804, test_loss = 0.8784
# # of parameters = 5, train_loss = 0.1950, test_loss = 1.1339
# # of parameters = 6, train_loss = 0.1947, test_loss = 1.1606
# # of parameters = 7, train_loss = 0.1449, test_loss = 2.5925
# # of parameters = 8, train_loss = 0.1439, test_loss = 2.5363
# # of parameters = 9, train_loss = 0.1439, test_loss = 3.3783
# # of parameters = 10, train_loss = 0.0000, test_loss = 3696.3345
# # of parameters = 11, train_loss = 0.0000, test_loss = 413.9523
# # of parameters = 12, train_loss = 0.0000, test_loss = 334.7963
# # of parameters = 13, train_loss = 0.0000, test_loss = 40.2138
# # of parameters = 14, train_loss = 0.0000, test_loss = 39.9888
# # of parameters = 15, train_loss = 0.0000, test_loss = 12.8322
# # of parameters = 16, train_loss = 0.0000, test_loss = 12.8285
# # of parameters = 17, train_loss = 0.0000, test_loss = 6.6283
# # of parameters = 18, train_loss = 0.0000, test_loss = 5.6831
# # of parameters = 19, train_loss = 0.0000, test_loss = 4.8672
# # of parameters = 20, train_loss = 0.0000, test_loss = 2.7735
# # of parameters = 21, train_loss = 0.0000, test_loss = 2.8320
# # of parameters = 22, train_loss = 0.0000, test_loss = 1.2087
# # of parameters = 23, train_loss = 0.0000, test_loss = 1.2170
# # of parameters = 24, train_loss = 0.0000, test_loss = 0.6976
# # of parameters = 25, train_loss = 0.0000, test_loss = 0.6651
# # of parameters = 26, train_loss = 0.0000, test_loss = 0.5706
# # of parameters = 27, train_loss = 0.0000, test_loss = 0.5612
# # of parameters = 28, train_loss = 0.0000, test_loss = 0.5339
# # of parameters = 29, train_loss = 0.0000, test_loss = 0.5662
# # of parameters = 30, train_loss = 0.0000, test_loss = 0.5649
# # of parameters = 31, train_loss = 0.0000, test_loss = 0.6007
# # of parameters = 32, train_loss = 0.0000, test_loss = 0.6052
# # of parameters = 33, train_loss = 0.0000, test_loss = 0.6239
# # of parameters = 34, train_loss = 0.0000, test_loss = 0.6244
# # of parameters = 35, train_loss = 0.0000, test_loss = 0.6388
# # of parameters = 36, train_loss = 0.0000, test_loss = 0.6333
# # of parameters = 37, train_loss = 0.0000, test_loss = 0.6332
# # of parameters = 38, train_loss = 0.0000, test_loss = 0.6211
# # of parameters = 39, train_loss = 0.0000, test_loss = 0.6215
# # of parameters = 40, train_loss = 0.0000, test_loss = 0.6155
# # of parameters = 41, train_loss = 0.0000, test_loss = 0.6277
# # of parameters = 42, train_loss = 0.0000, test_loss = 0.6172
# # of parameters = 43, train_loss = 0.0000, test_loss = 0.6305
# # of parameters = 44, train_loss = 0.0000, test_loss = 0.6271
# # of parameters = 45, train_loss = 0.0000, test_loss = 0.6339
# # of parameters = 46, train_loss = 0.0000, test_loss = 0.6338
# # of parameters = 47, train_loss = 0.0000, test_loss = 0.6351
# # of parameters = 48, train_loss = 0.0000, test_loss = 0.6366
# # of parameters = 49, train_loss = 0.0000, test_loss = 0.6366
# # of parameters = 50, train_loss = 0.0000, test_loss = 0.6411
# # of parameters = 51, train_loss = 0.0000, test_loss = 0.6403
# # of parameters = 52, train_loss = 0.0000, test_loss = 0.6387
# # of parameters = 53, train_loss = 0.0000, test_loss = 0.6403
# # of parameters = 54, train_loss = 0.0000, test_loss = 0.6444
# # of parameters = 55, train_loss = 0.0000, test_loss = 0.6424
# # of parameters = 56, train_loss = 0.0000, test_loss = 0.6410
# # of parameters = 57, train_loss = 0.0000, test_loss = 0.6412
# # of parameters = 58, train_loss = 0.0000, test_loss = 0.6425
# # of parameters = 59, train_loss = 0.0000, test_loss = 0.6423
# # of parameters = 60, train_loss = 0.0000, test_loss = 0.6422
# # of parameters = 61, train_loss = 0.0000, test_loss = 0.6427
# # of parameters = 62, train_loss = 0.0000, test_loss = 0.6398
# # of parameters = 63, train_loss = 0.0000, test_loss = 0.6442
# # of parameters = 64, train_loss = 0.0000, test_loss = 0.6426
# # of parameters = 65, train_loss = 0.0000, test_loss = 0.6456
# # of parameters = 66, train_loss = 0.0000, test_loss = 0.6394
# # of parameters = 67, train_loss = 0.0000, test_loss = 0.6435
# # of parameters = 68, train_loss = 0.0000, test_loss = 0.6428
# # of parameters = 69, train_loss = 0.0000, test_loss = 0.6436
# # of parameters = 70, train_loss = 0.0000, test_loss = 0.6423
# # of parameters = 71, train_loss = 0.0000, test_loss = 0.6426
# # of parameters = 72, train_loss = 0.0000, test_loss = 0.6437
# # of parameters = 73, train_loss = 0.0000, test_loss = 0.6448
# # of parameters = 74, train_loss = 0.0000, test_loss = 0.6465
# # of parameters = 75, train_loss = 0.0000, test_loss = 0.6469
# # of parameters = 76, train_loss = 0.0000, test_loss = 0.6463
# # of parameters = 77, train_loss = 0.0000, test_loss = 0.6473
# # of parameters = 78, train_loss = 0.0000, test_loss = 0.6462
# # of parameters = 79, train_loss = 0.0000, test_loss = 0.6457
# # of parameters = 80, train_loss = 0.0000, test_loss = 0.6431
# # of parameters = 81, train_loss = 0.0000, test_loss = 0.6430
# # of parameters = 82, train_loss = 0.0000, test_loss = 0.6446
# # of parameters = 83, train_loss = 0.0000, test_loss = 0.6439
# # of parameters = 84, train_loss = 0.0000, test_loss = 0.6434
# # of parameters = 85, train_loss = 0.0000, test_loss = 0.6437
# # of parameters = 86, train_loss = 0.0000, test_loss = 0.6462
# # of parameters = 87, train_loss = 0.0000, test_loss = 0.6459
# # of parameters = 88, train_loss = 0.0000, test_loss = 0.6459
# # of parameters = 89, train_loss = 0.0000, test_loss = 0.6461
# # of parameters = 90, train_loss = 0.0000, test_loss = 0.6450
# # of parameters = 91, train_loss = 0.0000, test_loss = 0.6452
# # of parameters = 92, train_loss = 0.0000, test_loss = 0.6476
# # of parameters = 93, train_loss = 0.0000, test_loss = 0.6472
# # of parameters = 94, train_loss = 0.0000, test_loss = 0.6462
# # of parameters = 95, train_loss = 0.0000, test_loss = 0.6461
# # of parameters = 96, train_loss = 0.0000, test_loss = 0.6478
# # of parameters = 97, train_loss = 0.0000, test_loss = 0.6473
# # of parameters = 98, train_loss = 0.0000, test_loss = 0.6471
# # of parameters = 99, train_loss = 0.0000, test_loss = 0.6468
# # of parameters = 100, train_loss = 0.0000, test_loss = 0.6460
# # of parameters = 101, train_loss = 0.0000, test_loss = 0.6465
# # of parameters = 102, train_loss = 0.0000, test_loss = 0.6464
# # of parameters = 103, train_loss = 0.0000, test_loss = 0.6463
# # of parameters = 104, train_loss = 0.0000, test_loss = 0.6440
# # of parameters = 105, train_loss = 0.0000, test_loss = 0.6449
# # of parameters = 106, train_loss = 0.0000, test_loss = 0.6445
# # of parameters = 107, train_loss = 0.0000, test_loss = 0.6440
# # of parameters = 108, train_loss = 0.0000, test_loss = 0.6434
# # of parameters = 109, train_loss = 0.0000, test_loss = 0.6434
# # of parameters = 110, train_loss = 0.0000, test_loss = 0.6435
# # of parameters = 111, train_loss = 0.0000, test_loss = 0.6435
# # of parameters = 112, train_loss = 0.0000, test_loss = 0.6439
# # of parameters = 113, train_loss = 0.0000, test_loss = 0.6438
# # of parameters = 114, train_loss = 0.0000, test_loss = 0.6441
# # of parameters = 115, train_loss = 0.0000, test_loss = 0.6443
# # of parameters = 116, train_loss = 0.0000, test_loss = 0.6442
# # of parameters = 117, train_loss = 0.0000, test_loss = 0.6438
# # of parameters = 118, train_loss = 0.0000, test_loss = 0.6443
# # of parameters = 119, train_loss = 0.0000, test_loss = 0.6450
# # of parameters = 120, train_loss = 0.0000, test_loss = 0.6445
# # of parameters = 121, train_loss = 0.0000, test_loss = 0.6435
# # of parameters = 122, train_loss = 0.0000, test_loss = 0.6426
# # of parameters = 123, train_loss = 0.0000, test_loss = 0.6424
# # of parameters = 124, train_loss = 0.0000, test_loss = 0.6425
# # of parameters = 125, train_loss = 0.0000, test_loss = 0.6422
# # of parameters = 126, train_loss = 0.0000, test_loss = 0.6420
# # of parameters = 127, train_loss = 0.0000, test_loss = 0.6426
# # of parameters = 128, train_loss = 0.0000, test_loss = 0.6422
# # of parameters = 129, train_loss = 0.0000, test_loss = 0.6421
# # of parameters = 130, train_loss = 0.0000, test_loss = 0.6423
# # of parameters = 131, train_loss = 0.0000, test_loss = 0.6422
# # of parameters = 132, train_loss = 0.0000, test_loss = 0.6411
# # of parameters = 133, train_loss = 0.0000, test_loss = 0.6411
# # of parameters = 134, train_loss = 0.0000, test_loss = 0.6415
# # of parameters = 135, train_loss = 0.0000, test_loss = 0.6411
# # of parameters = 136, train_loss = 0.0000, test_loss = 0.6405
# # of parameters = 137, train_loss = 0.0000, test_loss = 0.6407
# # of parameters = 138, train_loss = 0.0000, test_loss = 0.6407
# # of parameters = 139, train_loss = 0.0000, test_loss = 0.6407
# # of parameters = 140, train_loss = 0.0000, test_loss = 0.6408
# # of parameters = 141, train_loss = 0.0000, test_loss = 0.6410
# # of parameters = 142, train_loss = 0.0000, test_loss = 0.6402
# # of parameters = 143, train_loss = 0.0000, test_loss = 0.6406
# # of parameters = 144, train_loss = 0.0000, test_loss = 0.6404
# # of parameters = 145, train_loss = 0.0000, test_loss = 0.6406
# # of parameters = 146, train_loss = 0.0000, test_loss = 0.6400
# # of parameters = 147, train_loss = 0.0000, test_loss = 0.6399
# # of parameters = 148, train_loss = 0.0000, test_loss = 0.6403
# # of parameters = 149, train_loss = 0.0000, test_loss = 0.6398
# # of parameters = 150, train_loss = 0.0000, test_loss = 0.6397
# # of parameters = 151, train_loss = 0.0000, test_loss = 0.6404
# # of parameters = 152, train_loss = 0.0000, test_loss = 0.6407
# # of parameters = 153, train_loss = 0.0000, test_loss = 0.6410
# # of parameters = 154, train_loss = 0.0000, test_loss = 0.6410
# # of parameters = 155, train_loss = 0.0000, test_loss = 0.6412
# # of parameters = 156, train_loss = 0.0000, test_loss = 0.6410
# # of parameters = 157, train_loss = 0.0000, test_loss = 0.6407
# # of parameters = 158, train_loss = 0.0000, test_loss = 0.6414
# # of parameters = 159, train_loss = 0.0000, test_loss = 0.6412
# # of parameters = 160, train_loss = 0.0000, test_loss = 0.6409
# # of parameters = 161, train_loss = 0.0000, test_loss = 0.6403
# # of parameters = 162, train_loss = 0.0000, test_loss = 0.6414
# # of parameters = 163, train_loss = 0.0000, test_loss = 0.6414
# # of parameters = 164, train_loss = 0.0000, test_loss = 0.6410
# # of parameters = 165, train_loss = 0.0000, test_loss = 0.6407
# # of parameters = 166, train_loss = 0.0000, test_loss = 0.6407
# # of parameters = 167, train_loss = 0.0000, test_loss = 0.6410
# # of parameters = 168, train_loss = 0.0000, test_loss = 0.6412
# # of parameters = 169, train_loss = 0.0000, test_loss = 0.6412
# # of parameters = 170, train_loss = 0.0000, test_loss = 0.6414
# # of parameters = 171, train_loss = 0.0000, test_loss = 0.6416
# # of parameters = 172, train_loss = 0.0000, test_loss = 0.6425
# # of parameters = 173, train_loss = 0.0000, test_loss = 0.6422
# # of parameters = 174, train_loss = 0.0000, test_loss = 0.6420
# # of parameters = 175, train_loss = 0.0000, test_loss = 0.6419
# # of parameters = 176, train_loss = 0.0000, test_loss = 0.6423
# # of parameters = 177, train_loss = 0.0000, test_loss = 0.6421
# # of parameters = 178, train_loss = 0.0000, test_loss = 0.6422
# # of parameters = 179, train_loss = 0.0000, test_loss = 0.6422
# # of parameters = 180, train_loss = 0.0000, test_loss = 0.6425
# # of parameters = 181, train_loss = 0.0000, test_loss = 0.6426
# # of parameters = 182, train_loss = 0.0000, test_loss = 0.6425
# # of parameters = 183, train_loss = 0.0000, test_loss = 0.6426
# # of parameters = 184, train_loss = 0.0000, test_loss = 0.6430
# # of parameters = 185, train_loss = 0.0000, test_loss = 0.6429
# # of parameters = 186, train_loss = 0.0000, test_loss = 0.6429
# # of parameters = 187, train_loss = 0.0000, test_loss = 0.6428
# # of parameters = 188, train_loss = 0.0000, test_loss = 0.6428
# # of parameters = 189, train_loss = 0.0000, test_loss = 0.6428
# # of parameters = 190, train_loss = 0.0000, test_loss = 0.6430
# # of parameters = 191, train_loss = 0.0000, test_loss = 0.6429
# # of parameters = 192, train_loss = 0.0000, test_loss = 0.6427
# # of parameters = 193, train_loss = 0.0000, test_loss = 0.6428
# # of parameters = 194, train_loss = 0.0000, test_loss = 0.6435
# # of parameters = 195, train_loss = 0.0000, test_loss = 0.6434
# # of parameters = 196, train_loss = 0.0000, test_loss = 0.6436
# # of parameters = 197, train_loss = 0.0000, test_loss = 0.6435
# # of parameters = 198, train_loss = 0.0000, test_loss = 0.6430
# # of parameters = 199, train_loss = 0.0000, test_loss = 0.6427
# # of parameters = 200, train_loss = 0.0000, test_loss = 0.6429

# %%
y_lower, y_upper = -5, 5

# We plot the objective function, fitted function and training data
degree = 1
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 10
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 100
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 200
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)

# %%
plot_double_descent(output_df, n_samples)

# %% [markdown]
# \

# %% [markdown]
# ## **1.3 Third experiment $(e^{3x} + cos(25x))$**

# %%
def objective_function(x):
  '''
  Objective function (unknown) we want to approximate using training data. In this
  case we use y(x) = exp(3x) + cos(25x) as objective function

  '''
  return np.float64(np.exp(3*x) + np.cos(25*x))

# %% [markdown]
# The new objective function changes the trend function ($2x$) from linear to exponential ($e^{3x}$).

# %%
plot_objective_function(objective_function, "$e^{3x} + cos(25x)$")

# %%
# Here we generate the training data and we plot them together with the objective function
lower_bound, higher_bound = -1.0, 1.0
X_test = np.linspace(lower_bound, higher_bound, num=1000)
y_test = objective_function(X_test)
n_samples = 10
X_train, y_train = generate_training_data(lower_bound, higher_bound, n_samples, objective_function)
plot_objective_function_and_training_data(X_train, y_train, X_test, y_test)

# %%
output = []

from sklearn.metrics import mean_squared_error

# Number of params we want to use for the approximation
degrees = list(range(1, 201))

# For each degree in [1, 200] we calculate the fitted function and see how it fits the objective function by using MSE in training and test.
for degree in degrees:
  X_train_poly, y_train_pred, y_test_pred = fit_legendre_polynomial_regression(degree, X_train, y_train, X_test)

  # We calculate the MSE for the training and test data
  train_error = mean_squared_error(y_train, y_train_pred)
  test_error = mean_squared_error(y_test, y_test_pred)

  # We print the degree and both the MSE in training and the MSE in test for that approximation
  print(f"# of parameters = {degree}, train_error = {train_error:.4f}, test_error = {test_error:.4f}")

  # We save all the results so we can use them lately
  output.append({"# of parameters": degree, "X_train_poly": X_train_poly, "train_error": train_error, "test_error": test_error, "y_test_pred": y_test_pred})

# We convert the output into a pandas dataframe
output_df = pd.DataFrame(output)
# Out:
# # of parameters = 1, train_loss = 16.7362, test_loss = 21.2694
# # of parameters = 2, train_loss = 5.4321, test_loss = 15.6398
# # of parameters = 3, train_loss = 5.2819, test_loss = 16.3595
# # of parameters = 4, train_loss = 5.0382, test_loss = 19.1101
# # of parameters = 5, train_loss = 0.6786, test_loss = 78.2505
# # of parameters = 6, train_loss = 0.4714, test_loss = 58.3433
# # of parameters = 7, train_loss = 0.0798, test_loss = 267.6263
# # of parameters = 8, train_loss = 0.0222, test_loss = 10986.1558
# # of parameters = 9, train_loss = 0.0001, test_loss = 1315001.7969
# # of parameters = 10, train_loss = 0.0000, test_loss = 11672471.7404
# # of parameters = 11, train_loss = 0.0000, test_loss = 288766.1471
# # of parameters = 12, train_loss = 0.0000, test_loss = 46516.6357
# # of parameters = 13, train_loss = 0.0000, test_loss = 9021.3742
# # of parameters = 14, train_loss = 0.0000, test_loss = 3944.3192
# # of parameters = 15, train_loss = 0.0000, test_loss = 1897.9095
# # of parameters = 16, train_loss = 0.0000, test_loss = 345.4485
# # of parameters = 17, train_loss = 0.0000, test_loss = 88.7591
# # of parameters = 18, train_loss = 0.0000, test_loss = 78.8532
# # of parameters = 19, train_loss = 0.0000, test_loss = 61.3831
# # of parameters = 20, train_loss = 0.0000, test_loss = 37.9886
# # of parameters = 21, train_loss = 0.0000, test_loss = 27.4982
# # of parameters = 22, train_loss = 0.0000, test_loss = 27.2972
# # of parameters = 23, train_loss = 0.0000, test_loss = 23.2585
# # of parameters = 24, train_loss = 0.0000, test_loss = 22.5050
# # of parameters = 25, train_loss = 0.0000, test_loss = 22.3741
# # of parameters = 26, train_loss = 0.0000, test_loss = 22.1009
# # of parameters = 27, train_loss = 0.0000, test_loss = 21.6451
# # of parameters = 28, train_loss = 0.0000, test_loss = 21.5177
# # of parameters = 29, train_loss = 0.0000, test_loss = 21.2330
# # of parameters = 30, train_loss = 0.0000, test_loss = 20.0359
# # of parameters = 31, train_loss = 0.0000, test_loss = 20.0375
# # of parameters = 32, train_loss = 0.0000, test_loss = 19.9797
# # of parameters = 33, train_loss = 0.0000, test_loss = 19.9260
# # of parameters = 34, train_loss = 0.0000, test_loss = 19.9389
# # of parameters = 35, train_loss = 0.0000, test_loss = 20.0625
# # of parameters = 36, train_loss = 0.0000, test_loss = 19.8835
# # of parameters = 37, train_loss = 0.0000, test_loss = 19.8963
# # of parameters = 38, train_loss = 0.0000, test_loss = 19.4265
# # of parameters = 39, train_loss = 0.0000, test_loss = 19.2753
# # of parameters = 40, train_loss = 0.0000, test_loss = 19.2233
# # of parameters = 41, train_loss = 0.0000, test_loss = 19.1072
# # of parameters = 42, train_loss = 0.0000, test_loss = 19.0806
# # of parameters = 43, train_loss = 0.0000, test_loss = 19.0435
# # of parameters = 44, train_loss = 0.0000, test_loss = 18.9841
# # of parameters = 45, train_loss = 0.0000, test_loss = 18.9696
# # of parameters = 46, train_loss = 0.0000, test_loss = 18.9228
# # of parameters = 47, train_loss = 0.0000, test_loss = 18.6895
# # of parameters = 48, train_loss = 0.0000, test_loss = 18.7150
# # of parameters = 49, train_loss = 0.0000, test_loss = 18.7200
# # of parameters = 50, train_loss = 0.0000, test_loss = 18.7486
# # of parameters = 51, train_loss = 0.0000, test_loss = 18.7444
# # of parameters = 52, train_loss = 0.0000, test_loss = 18.7745
# # of parameters = 53, train_loss = 0.0000, test_loss = 18.7656
# # of parameters = 54, train_loss = 0.0000, test_loss = 18.7631
# # of parameters = 55, train_loss = 0.0000, test_loss = 18.7419
# # of parameters = 56, train_loss = 0.0000, test_loss = 18.6665
# # of parameters = 57, train_loss = 0.0000, test_loss = 18.6134
# # of parameters = 58, train_loss = 0.0000, test_loss = 18.6132
# # of parameters = 59, train_loss = 0.0000, test_loss = 18.6192
# # of parameters = 60, train_loss = 0.0000, test_loss = 18.5516
# # of parameters = 61, train_loss = 0.0000, test_loss = 18.5551
# # of parameters = 62, train_loss = 0.0000, test_loss = 18.5713
# # of parameters = 63, train_loss = 0.0000, test_loss = 18.5969
# # of parameters = 64, train_loss = 0.0000, test_loss = 18.5999
# # of parameters = 65, train_loss = 0.0000, test_loss = 18.5910
# # of parameters = 66, train_loss = 0.0000, test_loss = 18.5007
# # of parameters = 67, train_loss = 0.0000, test_loss = 18.3466
# # of parameters = 68, train_loss = 0.0000, test_loss = 18.3504
# # of parameters = 69, train_loss = 0.0000, test_loss = 18.3313
# # of parameters = 70, train_loss = 0.0000, test_loss = 18.3206
# # of parameters = 71, train_loss = 0.0000, test_loss = 18.3219
# # of parameters = 72, train_loss = 0.0000, test_loss = 18.3155
# # of parameters = 73, train_loss = 0.0000, test_loss = 18.1647
# # of parameters = 74, train_loss = 0.0000, test_loss = 18.1614
# # of parameters = 75, train_loss = 0.0000, test_loss = 18.1528
# # of parameters = 76, train_loss = 0.0000, test_loss = 18.1606
# # of parameters = 77, train_loss = 0.0000, test_loss = 18.1321
# # of parameters = 78, train_loss = 0.0000, test_loss = 18.2186
# # of parameters = 79, train_loss = 0.0000, test_loss = 18.2505
# # of parameters = 80, train_loss = 0.0000, test_loss = 18.2547
# # of parameters = 81, train_loss = 0.0000, test_loss = 18.1861
# # of parameters = 82, train_loss = 0.0000, test_loss = 18.1860
# # of parameters = 83, train_loss = 0.0000, test_loss = 18.0846
# # of parameters = 84, train_loss = 0.0000, test_loss = 17.9300
# # of parameters = 85, train_loss = 0.0000, test_loss = 17.9263
# # of parameters = 86, train_loss = 0.0000, test_loss = 17.9041
# # of parameters = 87, train_loss = 0.0000, test_loss = 17.9020
# # of parameters = 88, train_loss = 0.0000, test_loss = 17.8782
# # of parameters = 89, train_loss = 0.0000, test_loss = 17.8577
# # of parameters = 90, train_loss = 0.0000, test_loss = 17.8473
# # of parameters = 91, train_loss = 0.0000, test_loss = 17.8631
# # of parameters = 92, train_loss = 0.0000, test_loss = 17.8489
# # of parameters = 93, train_loss = 0.0000, test_loss = 17.8042
# # of parameters = 94, train_loss = 0.0000, test_loss = 17.8103
# # of parameters = 95, train_loss = 0.0000, test_loss = 17.7627
# # of parameters = 96, train_loss = 0.0000, test_loss = 17.7601
# # of parameters = 97, train_loss = 0.0000, test_loss = 17.7493
# # of parameters = 98, train_loss = 0.0000, test_loss = 17.7565
# # of parameters = 99, train_loss = 0.0000, test_loss = 17.7316
# # of parameters = 100, train_loss = 0.0000, test_loss = 17.7108
# # of parameters = 101, train_loss = 0.0000, test_loss = 17.7315
# # of parameters = 102, train_loss = 0.0000, test_loss = 17.7315
# # of parameters = 103, train_loss = 0.0000, test_loss = 17.6757
# # of parameters = 104, train_loss = 0.0000, test_loss = 17.7021
# # of parameters = 105, train_loss = 0.0000, test_loss = 17.7142
# # of parameters = 106, train_loss = 0.0000, test_loss = 17.7534
# # of parameters = 107, train_loss = 0.0000, test_loss = 17.7736
# # of parameters = 108, train_loss = 0.0000, test_loss = 17.7978
# # of parameters = 109, train_loss = 0.0000, test_loss = 17.7900
# # of parameters = 110, train_loss = 0.0000, test_loss = 17.7407
# # of parameters = 111, train_loss = 0.0000, test_loss = 17.7425
# # of parameters = 112, train_loss = 0.0000, test_loss = 17.7386
# # of parameters = 113, train_loss = 0.0000, test_loss = 17.7150
# # of parameters = 114, train_loss = 0.0000, test_loss = 17.6899
# # of parameters = 115, train_loss = 0.0000, test_loss = 17.6737
# # of parameters = 116, train_loss = 0.0000, test_loss = 17.6738
# # of parameters = 117, train_loss = 0.0000, test_loss = 17.6764
# # of parameters = 118, train_loss = 0.0000, test_loss = 17.6828
# # of parameters = 119, train_loss = 0.0000, test_loss = 17.6894
# # of parameters = 120, train_loss = 0.0000, test_loss = 17.6574
# # of parameters = 121, train_loss = 0.0000, test_loss = 17.6574
# # of parameters = 122, train_loss = 0.0000, test_loss = 17.6420
# # of parameters = 123, train_loss = 0.0000, test_loss = 17.6449
# # of parameters = 124, train_loss = 0.0000, test_loss = 17.6452
# # of parameters = 125, train_loss = 0.0000, test_loss = 17.6397
# # of parameters = 126, train_loss = 0.0000, test_loss = 17.6181
# # of parameters = 127, train_loss = 0.0000, test_loss = 17.6083
# # of parameters = 128, train_loss = 0.0000, test_loss = 17.6079
# # of parameters = 129, train_loss = 0.0000, test_loss = 17.6095
# # of parameters = 130, train_loss = 0.0000, test_loss = 17.6000
# # of parameters = 131, train_loss = 0.0000, test_loss = 17.5998
# # of parameters = 132, train_loss = 0.0000, test_loss = 17.6188
# # of parameters = 133, train_loss = 0.0000, test_loss = 17.6115
# # of parameters = 134, train_loss = 0.0000, test_loss = 17.6444
# # of parameters = 135, train_loss = 0.0000, test_loss = 17.6580
# # of parameters = 136, train_loss = 0.0000, test_loss = 17.6691
# # of parameters = 137, train_loss = 0.0000, test_loss = 17.6700
# # of parameters = 138, train_loss = 0.0000, test_loss = 17.6705
# # of parameters = 139, train_loss = 0.0000, test_loss = 17.6521
# # of parameters = 140, train_loss = 0.0000, test_loss = 17.5780
# # of parameters = 141, train_loss = 0.0000, test_loss = 17.5801
# # of parameters = 142, train_loss = 0.0000, test_loss = 17.5829
# # of parameters = 143, train_loss = 0.0000, test_loss = 17.5833
# # of parameters = 144, train_loss = 0.0000, test_loss = 17.5715
# # of parameters = 145, train_loss = 0.0000, test_loss = 17.5881
# # of parameters = 146, train_loss = 0.0000, test_loss = 17.5897
# # of parameters = 147, train_loss = 0.0000, test_loss = 17.5978
# # of parameters = 148, train_loss = 0.0000, test_loss = 17.6019
# # of parameters = 149, train_loss = 0.0000, test_loss = 17.6085
# # of parameters = 150, train_loss = 0.0000, test_loss = 17.5766
# # of parameters = 151, train_loss = 0.0000, test_loss = 17.5762
# # of parameters = 152, train_loss = 0.0000, test_loss = 17.5801
# # of parameters = 153, train_loss = 0.0000, test_loss = 17.5795
# # of parameters = 154, train_loss = 0.0000, test_loss = 17.5804
# # of parameters = 155, train_loss = 0.0000, test_loss = 17.5812
# # of parameters = 156, train_loss = 0.0000, test_loss = 17.5729
# # of parameters = 157, train_loss = 0.0000, test_loss = 17.5634
# # of parameters = 158, train_loss = 0.0000, test_loss = 17.5632
# # of parameters = 159, train_loss = 0.0000, test_loss = 17.5547
# # of parameters = 160, train_loss = 0.0000, test_loss = 17.5541
# # of parameters = 161, train_loss = 0.0000, test_loss = 17.5718
# # of parameters = 162, train_loss = 0.0000, test_loss = 17.5880
# # of parameters = 163, train_loss = 0.0000, test_loss = 17.5958
# # of parameters = 164, train_loss = 0.0000, test_loss = 17.6076
# # of parameters = 165, train_loss = 0.0000, test_loss = 17.6101
# # of parameters = 166, train_loss = 0.0000, test_loss = 17.5743
# # of parameters = 167, train_loss = 0.0000, test_loss = 17.5584
# # of parameters = 168, train_loss = 0.0000, test_loss = 17.5617
# # of parameters = 169, train_loss = 0.0000, test_loss = 17.5630
# # of parameters = 170, train_loss = 0.0000, test_loss = 17.5492
# # of parameters = 171, train_loss = 0.0000, test_loss = 17.5505
# # of parameters = 172, train_loss = 0.0000, test_loss = 17.5516
# # of parameters = 173, train_loss = 0.0000, test_loss = 17.5535
# # of parameters = 174, train_loss = 0.0000, test_loss = 17.5503
# # of parameters = 175, train_loss = 0.0000, test_loss = 17.5566
# # of parameters = 176, train_loss = 0.0000, test_loss = 17.5306
# # of parameters = 177, train_loss = 0.0000, test_loss = 17.5271
# # of parameters = 178, train_loss = 0.0000, test_loss = 17.5315
# # of parameters = 179, train_loss = 0.0000, test_loss = 17.5289
# # of parameters = 180, train_loss = 0.0000, test_loss = 17.5349
# # of parameters = 181, train_loss = 0.0000, test_loss = 17.5359
# # of parameters = 182, train_loss = 0.0000, test_loss = 17.5355
# # of parameters = 183, train_loss = 0.0000, test_loss = 17.5247
# # of parameters = 184, train_loss = 0.0000, test_loss = 17.5177
# # of parameters = 185, train_loss = 0.0000, test_loss = 17.5177
# # of parameters = 186, train_loss = 0.0000, test_loss = 17.5098
# # of parameters = 187, train_loss = 0.0000, test_loss = 17.5077
# # of parameters = 188, train_loss = 0.0000, test_loss = 17.5171
# # of parameters = 189, train_loss = 0.0000, test_loss = 17.5277
# # of parameters = 190, train_loss = 0.0000, test_loss = 17.5497
# # of parameters = 191, train_loss = 0.0000, test_loss = 17.5582
# # of parameters = 192, train_loss = 0.0000, test_loss = 17.5638
# # of parameters = 193, train_loss = 0.0000, test_loss = 17.5588
# # of parameters = 194, train_loss = 0.0000, test_loss = 17.5565
# # of parameters = 195, train_loss = 0.0000, test_loss = 17.5563
# # of parameters = 196, train_loss = 0.0000, test_loss = 17.5326
# # of parameters = 197, train_loss = 0.0000, test_loss = 17.5222
# # of parameters = 198, train_loss = 0.0000, test_loss = 17.5224
# # of parameters = 199, train_loss = 0.0000, test_loss = 17.5158
# # of parameters = 200, train_loss = 0.0000, test_loss = 17.5091

# %%
y_lower, y_upper = -5, 25

# We plot the objective function, fitted function and training data
degree = 1
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 10
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 100
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 200
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)

# %%
plot_double_descent(output_df, n_samples)

# %% [markdown]
# \

# %% [markdown]
# ## **1.4 Fourth experiment $(tanh(x))$**

# %%
def objective_function4(x):
  '''
  Objective function (unknown) we want to approximate using training data. In this
  case we use y(x) = tanh(x) as objective function

  '''
  return np.float64(np.tanh(x))

# %% [markdown]
# The new objective function changes the trend function ($2x$) from linear to hyperbolic ($tanh(x)$) and the "noise" function ($cos(25x)$) has been removed.

# %%
plot_objective_function(objective_function4, "$tanh(x)$", -10, 10)

# %%
# Here we generate the training data and we plot them together with the objective function
lower_bound, higher_bound = -10.0, 10.0
X_test = np.linspace(lower_bound, higher_bound, num=1000)
y_test = objective_function4(X_test)
# Normalizar X_test al rango [-1, 1]
X_test = 2 * (X_test - lower_bound) / (higher_bound - lower_bound) - 1
n_samples = 10
X_train, y_train = generate_uniformly_distributed_training_data(lower_bound, higher_bound, n_samples, objective_function4)
plot_objective_function_and_training_data(X_train, y_train, X_test, y_test)

# %%
output = []

from sklearn.metrics import mean_squared_error

# Number of params we want to use for the approximation
degrees = list(range(1, 201))

# For each degree in [1, 200] we calculate the fitted function and see how it fits the objective function by using MSE in training and test.
for degree in degrees:
  X_train_poly, y_train_pred, y_test_pred = fit_legendre_polynomial_regression(degree, X_train, y_train, X_test)

  # We calculate the MSE for the training and test data
  train_error = mean_squared_error(y_train, y_train_pred)
  test_error = mean_squared_error(y_test, y_test_pred)

  # We print the degree and both the MSE in training and the MSE in test for that approximation
  print(f"# of parameters = {degree}, train_error = {train_error:.4f}, test_error = {test_error:.4f}")

  # We save all the results so we can use them lately
  output.append({"# of parameters": degree, "X_train_poly": X_train_poly, "train_error": train_error, "test_error": test_error, "y_test_pred": y_test_pred})

# We convert the output into a pandas dataframe
output_df = pd.DataFrame(output)
# Out:
# # of parameters = 1, train_loss = 0.1240, test_loss = 0.1643
# # of parameters = 2, train_loss = 0.1240, test_loss = 0.1643
# # of parameters = 3, train_loss = 0.0494, test_loss = 0.0729
# # of parameters = 4, train_loss = 0.0483, test_loss = 0.0734
# # of parameters = 5, train_loss = 0.0233, test_loss = 0.0391
# # of parameters = 6, train_loss = 0.0090, test_loss = 0.2125
# # of parameters = 7, train_loss = 0.0003, test_loss = 0.0863
# # of parameters = 8, train_loss = 0.0001, test_loss = 0.1825
# # of parameters = 9, train_loss = 0.0000, test_loss = 0.3810
# # of parameters = 10, train_loss = 0.0000, test_loss = 0.2728
# # of parameters = 11, train_loss = 0.0000, test_loss = 0.0189
# # of parameters = 12, train_loss = 0.0000, test_loss = 0.0193
# # of parameters = 13, train_loss = 0.0000, test_loss = 0.0127
# # of parameters = 14, train_loss = 0.0000, test_loss = 0.0157
# # of parameters = 15, train_loss = 0.0000, test_loss = 0.0249
# # of parameters = 16, train_loss = 0.0000, test_loss = 0.0331
# # of parameters = 17, train_loss = 0.0000, test_loss = 0.0527
# # of parameters = 18, train_loss = 0.0000, test_loss = 0.0573
# # of parameters = 19, train_loss = 0.0000, test_loss = 0.0623
# # of parameters = 20, train_loss = 0.0000, test_loss = 0.0668
# # of parameters = 21, train_loss = 0.0000, test_loss = 0.0724
# # of parameters = 22, train_loss = 0.0000, test_loss = 0.0726
# # of parameters = 23, train_loss = 0.0000, test_loss = 0.0741
# # of parameters = 24, train_loss = 0.0000, test_loss = 0.0753
# # of parameters = 25, train_loss = 0.0000, test_loss = 0.0763
# # of parameters = 26, train_loss = 0.0000, test_loss = 0.0774
# # of parameters = 27, train_loss = 0.0000, test_loss = 0.0786
# # of parameters = 28, train_loss = 0.0000, test_loss = 0.0836
# # of parameters = 29, train_loss = 0.0000, test_loss = 0.0836
# # of parameters = 30, train_loss = 0.0000, test_loss = 0.0859
# # of parameters = 31, train_loss = 0.0000, test_loss = 0.0891
# # of parameters = 32, train_loss = 0.0000, test_loss = 0.0900
# # of parameters = 33, train_loss = 0.0000, test_loss = 0.0903
# # of parameters = 34, train_loss = 0.0000, test_loss = 0.0969
# # of parameters = 35, train_loss = 0.0000, test_loss = 0.0969
# # of parameters = 36, train_loss = 0.0000, test_loss = 0.1003
# # of parameters = 37, train_loss = 0.0000, test_loss = 0.1003
# # of parameters = 38, train_loss = 0.0000, test_loss = 0.1009
# # of parameters = 39, train_loss = 0.0000, test_loss = 0.1009
# # of parameters = 40, train_loss = 0.0000, test_loss = 0.1007
# # of parameters = 41, train_loss = 0.0000, test_loss = 0.1006
# # of parameters = 42, train_loss = 0.0000, test_loss = 0.1038
# # of parameters = 43, train_loss = 0.0000, test_loss = 0.1071
# # of parameters = 44, train_loss = 0.0000, test_loss = 0.1168
# # of parameters = 45, train_loss = 0.0000, test_loss = 0.1173
# # of parameters = 46, train_loss = 0.0000, test_loss = 0.1196
# # of parameters = 47, train_loss = 0.0000, test_loss = 0.1231
# # of parameters = 48, train_loss = 0.0000, test_loss = 0.1229
# # of parameters = 49, train_loss = 0.0000, test_loss = 0.1228
# # of parameters = 50, train_loss = 0.0000, test_loss = 0.1230
# # of parameters = 51, train_loss = 0.0000, test_loss = 0.1229
# # of parameters = 52, train_loss = 0.0000, test_loss = 0.1234
# # of parameters = 53, train_loss = 0.0000, test_loss = 0.1234
# # of parameters = 54, train_loss = 0.0000, test_loss = 0.1239
# # of parameters = 55, train_loss = 0.0000, test_loss = 0.1261
# # of parameters = 56, train_loss = 0.0000, test_loss = 0.1267
# # of parameters = 57, train_loss = 0.0000, test_loss = 0.1331
# # of parameters = 58, train_loss = 0.0000, test_loss = 0.1331
# # of parameters = 59, train_loss = 0.0000, test_loss = 0.1332
# # of parameters = 60, train_loss = 0.0000, test_loss = 0.1333
# # of parameters = 61, train_loss = 0.0000, test_loss = 0.1345
# # of parameters = 62, train_loss = 0.0000, test_loss = 0.1345
# # of parameters = 63, train_loss = 0.0000, test_loss = 0.1357
# # of parameters = 64, train_loss = 0.0000, test_loss = 0.1356
# # of parameters = 65, train_loss = 0.0000, test_loss = 0.1361
# # of parameters = 66, train_loss = 0.0000, test_loss = 0.1367
# # of parameters = 67, train_loss = 0.0000, test_loss = 0.1367
# # of parameters = 68, train_loss = 0.0000, test_loss = 0.1367
# # of parameters = 69, train_loss = 0.0000, test_loss = 0.1396
# # of parameters = 70, train_loss = 0.0000, test_loss = 0.1396
# # of parameters = 71, train_loss = 0.0000, test_loss = 0.1406
# # of parameters = 72, train_loss = 0.0000, test_loss = 0.1414
# # of parameters = 73, train_loss = 0.0000, test_loss = 0.1422
# # of parameters = 74, train_loss = 0.0000, test_loss = 0.1447
# # of parameters = 75, train_loss = 0.0000, test_loss = 0.1445
# # of parameters = 76, train_loss = 0.0000, test_loss = 0.1447
# # of parameters = 77, train_loss = 0.0000, test_loss = 0.1463
# # of parameters = 78, train_loss = 0.0000, test_loss = 0.1463
# # of parameters = 79, train_loss = 0.0000, test_loss = 0.1476
# # of parameters = 80, train_loss = 0.0000, test_loss = 0.1474
# # of parameters = 81, train_loss = 0.0000, test_loss = 0.1476
# # of parameters = 82, train_loss = 0.0000, test_loss = 0.1510
# # of parameters = 83, train_loss = 0.0000, test_loss = 0.1510
# # of parameters = 84, train_loss = 0.0000, test_loss = 0.1530
# # of parameters = 85, train_loss = 0.0000, test_loss = 0.1532
# # of parameters = 86, train_loss = 0.0000, test_loss = 0.1533
# # of parameters = 87, train_loss = 0.0000, test_loss = 0.1534
# # of parameters = 88, train_loss = 0.0000, test_loss = 0.1535
# # of parameters = 89, train_loss = 0.0000, test_loss = 0.1535
# # of parameters = 90, train_loss = 0.0000, test_loss = 0.1535
# # of parameters = 91, train_loss = 0.0000, test_loss = 0.1537
# # of parameters = 92, train_loss = 0.0000, test_loss = 0.1553
# # of parameters = 93, train_loss = 0.0000, test_loss = 0.1552
# # of parameters = 94, train_loss = 0.0000, test_loss = 0.1554
# # of parameters = 95, train_loss = 0.0000, test_loss = 0.1561
# # of parameters = 96, train_loss = 0.0000, test_loss = 0.1566
# # of parameters = 97, train_loss = 0.0000, test_loss = 0.1567
# # of parameters = 98, train_loss = 0.0000, test_loss = 0.1579
# # of parameters = 99, train_loss = 0.0000, test_loss = 0.1579
# # of parameters = 100, train_loss = 0.0000, test_loss = 0.1578
# # of parameters = 101, train_loss = 0.0000, test_loss = 0.1595
# # of parameters = 102, train_loss = 0.0000, test_loss = 0.1594
# # of parameters = 103, train_loss = 0.0000, test_loss = 0.1594
# # of parameters = 104, train_loss = 0.0000, test_loss = 0.1603
# # of parameters = 105, train_loss = 0.0000, test_loss = 0.1604
# # of parameters = 106, train_loss = 0.0000, test_loss = 0.1606
# # of parameters = 107, train_loss = 0.0000, test_loss = 0.1606
# # of parameters = 108, train_loss = 0.0000, test_loss = 0.1619
# # of parameters = 109, train_loss = 0.0000, test_loss = 0.1640
# # of parameters = 110, train_loss = 0.0000, test_loss = 0.1641
# # of parameters = 111, train_loss = 0.0000, test_loss = 0.1655
# # of parameters = 112, train_loss = 0.0000, test_loss = 0.1658
# # of parameters = 113, train_loss = 0.0000, test_loss = 0.1658
# # of parameters = 114, train_loss = 0.0000, test_loss = 0.1658
# # of parameters = 115, train_loss = 0.0000, test_loss = 0.1658
# # of parameters = 116, train_loss = 0.0000, test_loss = 0.1658
# # of parameters = 117, train_loss = 0.0000, test_loss = 0.1662
# # of parameters = 118, train_loss = 0.0000, test_loss = 0.1667
# # of parameters = 119, train_loss = 0.0000, test_loss = 0.1679
# # of parameters = 120, train_loss = 0.0000, test_loss = 0.1680
# # of parameters = 121, train_loss = 0.0000, test_loss = 0.1682
# # of parameters = 122, train_loss = 0.0000, test_loss = 0.1683
# # of parameters = 123, train_loss = 0.0000, test_loss = 0.1685
# # of parameters = 124, train_loss = 0.0000, test_loss = 0.1689
# # of parameters = 125, train_loss = 0.0000, test_loss = 0.1689
# # of parameters = 126, train_loss = 0.0000, test_loss = 0.1696
# # of parameters = 127, train_loss = 0.0000, test_loss = 0.1699
# # of parameters = 128, train_loss = 0.0000, test_loss = 0.1702
# # of parameters = 129, train_loss = 0.0000, test_loss = 0.1702
# # of parameters = 130, train_loss = 0.0000, test_loss = 0.1707
# # of parameters = 131, train_loss = 0.0000, test_loss = 0.1709
# # of parameters = 132, train_loss = 0.0000, test_loss = 0.1713
# # of parameters = 133, train_loss = 0.0000, test_loss = 0.1713
# # of parameters = 134, train_loss = 0.0000, test_loss = 0.1713
# # of parameters = 135, train_loss = 0.0000, test_loss = 0.1717
# # of parameters = 136, train_loss = 0.0000, test_loss = 0.1747
# # of parameters = 137, train_loss = 0.0000, test_loss = 0.1752
# # of parameters = 138, train_loss = 0.0000, test_loss = 0.1755
# # of parameters = 139, train_loss = 0.0000, test_loss = 0.1755
# # of parameters = 140, train_loss = 0.0000, test_loss = 0.1755
# # of parameters = 141, train_loss = 0.0000, test_loss = 0.1756
# # of parameters = 142, train_loss = 0.0000, test_loss = 0.1756
# # of parameters = 143, train_loss = 0.0000, test_loss = 0.1760
# # of parameters = 144, train_loss = 0.0000, test_loss = 0.1761
# # of parameters = 145, train_loss = 0.0000, test_loss = 0.1766
# # of parameters = 146, train_loss = 0.0000, test_loss = 0.1774
# # of parameters = 147, train_loss = 0.0000, test_loss = 0.1775
# # of parameters = 148, train_loss = 0.0000, test_loss = 0.1774
# # of parameters = 149, train_loss = 0.0000, test_loss = 0.1785
# # of parameters = 150, train_loss = 0.0000, test_loss = 0.1793
# # of parameters = 151, train_loss = 0.0000, test_loss = 0.1793
# # of parameters = 152, train_loss = 0.0000, test_loss = 0.1793
# # of parameters = 153, train_loss = 0.0000, test_loss = 0.1800
# # of parameters = 154, train_loss = 0.0000, test_loss = 0.1800
# # of parameters = 155, train_loss = 0.0000, test_loss = 0.1806
# # of parameters = 156, train_loss = 0.0000, test_loss = 0.1807
# # of parameters = 157, train_loss = 0.0000, test_loss = 0.1811
# # of parameters = 158, train_loss = 0.0000, test_loss = 0.1813
# # of parameters = 159, train_loss = 0.0000, test_loss = 0.1820
# # of parameters = 160, train_loss = 0.0000, test_loss = 0.1820
# # of parameters = 161, train_loss = 0.0000, test_loss = 0.1820
# # of parameters = 162, train_loss = 0.0000, test_loss = 0.1830
# # of parameters = 163, train_loss = 0.0000, test_loss = 0.1833
# # of parameters = 164, train_loss = 0.0000, test_loss = 0.1833
# # of parameters = 165, train_loss = 0.0000, test_loss = 0.1834
# # of parameters = 166, train_loss = 0.0000, test_loss = 0.1834
# # of parameters = 167, train_loss = 0.0000, test_loss = 0.1836
# # of parameters = 168, train_loss = 0.0000, test_loss = 0.1835
# # of parameters = 169, train_loss = 0.0000, test_loss = 0.1838
# # of parameters = 170, train_loss = 0.0000, test_loss = 0.1855
# # of parameters = 171, train_loss = 0.0000, test_loss = 0.1858
# # of parameters = 172, train_loss = 0.0000, test_loss = 0.1878
# # of parameters = 173, train_loss = 0.0000, test_loss = 0.1878
# # of parameters = 174, train_loss = 0.0000, test_loss = 0.1879
# # of parameters = 175, train_loss = 0.0000, test_loss = 0.1880
# # of parameters = 176, train_loss = 0.0000, test_loss = 0.1883
# # of parameters = 177, train_loss = 0.0000, test_loss = 0.1884
# # of parameters = 178, train_loss = 0.0000, test_loss = 0.1888
# # of parameters = 179, train_loss = 0.0000, test_loss = 0.1891
# # of parameters = 180, train_loss = 0.0000, test_loss = 0.1898
# # of parameters = 181, train_loss = 0.0000, test_loss = 0.1899
# # of parameters = 182, train_loss = 0.0000, test_loss = 0.1900
# # of parameters = 183, train_loss = 0.0000, test_loss = 0.1904
# # of parameters = 184, train_loss = 0.0000, test_loss = 0.1904
# # of parameters = 185, train_loss = 0.0000, test_loss = 0.1904
# # of parameters = 186, train_loss = 0.0000, test_loss = 0.1904
# # of parameters = 187, train_loss = 0.0000, test_loss = 0.1909
# # of parameters = 188, train_loss = 0.0000, test_loss = 0.1911
# # of parameters = 189, train_loss = 0.0000, test_loss = 0.1922
# # of parameters = 190, train_loss = 0.0000, test_loss = 0.1922
# # of parameters = 191, train_loss = 0.0000, test_loss = 0.1922
# # of parameters = 192, train_loss = 0.0000, test_loss = 0.1926
# # of parameters = 193, train_loss = 0.0000, test_loss = 0.1930
# # of parameters = 194, train_loss = 0.0000, test_loss = 0.1931
# # of parameters = 195, train_loss = 0.0000, test_loss = 0.1931
# # of parameters = 196, train_loss = 0.0000, test_loss = 0.1933
# # of parameters = 197, train_loss = 0.0000, test_loss = 0.1947
# # of parameters = 198, train_loss = 0.0000, test_loss = 0.1950
# # of parameters = 199, train_loss = 0.0000, test_loss = 0.1962
# # of parameters = 200, train_loss = 0.0000, test_loss = 0.1966

# %%
y_lower, y_upper = -3, 3

# We plot the objective function, fitted function and training data
degree = 1
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 10
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 100
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 200
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)

# %%
plot_double_descent(output_df, n_samples)

# %% [markdown]
# \

# %% [markdown]
# ### **$1.4.1 \: tanh(x) + cos(25x)$**

# %%
def objective_function4_1(x):
  '''
  Objective function (unknown) we want to approximate using training data. In this
  case we use y(x) = tanh(x) + cos(25x) as objective function

  '''
  return np.float64(np.tanh(x) + np.cos(25*x))

# %% [markdown]
# In this case we add the "noise" function ($cos(25x)$) to the previous trend function.

# %%
plot_objective_function(objective_function4_1, "$tanh(x) + cos(25x)$", -10, 10)

# %%
# Here we generate the training data and we plot them together with the objective function
lower_bound, higher_bound = -10.0, 10.0
X_test = np.linspace(lower_bound, higher_bound, num=1000)
y_test = objective_function4(X_test)
# Normalizar X_test al rango [-1, 1]
X_test = 2 * (X_test - lower_bound) / (higher_bound - lower_bound) - 1
n_samples = 10
X_train, y_train = generate_uniformly_distributed_training_data(lower_bound, higher_bound, n_samples, objective_function4)
plot_objective_function_and_training_data(X_train, y_train, X_test, y_test)

# %%
output = []

from sklearn.metrics import mean_squared_error

# Number of params we want to use for the approximation
degrees = list(range(1, 201))

# For each degree in [1, 200] we calculate the fitted function and see how it fits the objective function by using MSE in training and test.
for degree in degrees:
  X_train_poly, y_train_pred, y_test_pred = fit_legendre_polynomial_regression(degree, X_train, y_train, X_test)

  # We calculate the MSE for the training and test data
  train_error = mean_squared_error(y_train, y_train_pred)
  test_error = mean_squared_error(y_test, y_test_pred)

  # We print the degree and both the MSE in training and the MSE in test for that approximation
  print(f"# of parameters = {degree}, train_error = {train_error:.4f}, test_error = {test_error:.4f}")

  # We save all the results so we can use them lately
  output.append({"# of parameters": degree, "X_train_poly": X_train_poly, "train_error": train_error, "test_error": test_error, "y_test_pred": y_test_pred})

# We convert the output into a pandas dataframe
output_df = pd.DataFrame(output)
# Out:
# # of parameters = 1, train_loss = 0.3791, test_loss = 0.6911
# # of parameters = 2, train_loss = 0.3784, test_loss = 0.6892
# # of parameters = 3, train_loss = 0.3363, test_loss = 0.6143
# # of parameters = 4, train_loss = 0.3134, test_loss = 0.6969
# # of parameters = 5, train_loss = 0.2591, test_loss = 1.0451
# # of parameters = 6, train_loss = 0.1285, test_loss = 5.4548
# # of parameters = 7, train_loss = 0.1239, test_loss = 4.6132
# # of parameters = 8, train_loss = 0.1238, test_loss = 4.3285
# # of parameters = 9, train_loss = 0.0409, test_loss = 5.3119
# # of parameters = 10, train_loss = 0.0000, test_loss = 1029.4332
# # of parameters = 11, train_loss = 0.0000, test_loss = 40.4833
# # of parameters = 12, train_loss = 0.0000, test_loss = 34.6579
# # of parameters = 13, train_loss = 0.0000, test_loss = 8.2703
# # of parameters = 14, train_loss = 0.0000, test_loss = 2.3463
# # of parameters = 15, train_loss = 0.0000, test_loss = 2.3537
# # of parameters = 16, train_loss = 0.0000, test_loss = 1.7170
# # of parameters = 17, train_loss = 0.0000, test_loss = 1.2041
# # of parameters = 18, train_loss = 0.0000, test_loss = 1.1780
# # of parameters = 19, train_loss = 0.0000, test_loss = 1.1016
# # of parameters = 20, train_loss = 0.0000, test_loss = 1.0769
# # of parameters = 21, train_loss = 0.0000, test_loss = 1.0173
# # of parameters = 22, train_loss = 0.0000, test_loss = 1.0075
# # of parameters = 23, train_loss = 0.0000, test_loss = 0.9618
# # of parameters = 24, train_loss = 0.0000, test_loss = 0.9333
# # of parameters = 25, train_loss = 0.0000, test_loss = 0.9292
# # of parameters = 26, train_loss = 0.0000, test_loss = 0.9300
# # of parameters = 27, train_loss = 0.0000, test_loss = 0.8208
# # of parameters = 28, train_loss = 0.0000, test_loss = 0.8210
# # of parameters = 29, train_loss = 0.0000, test_loss = 0.8067
# # of parameters = 30, train_loss = 0.0000, test_loss = 0.8045
# # of parameters = 31, train_loss = 0.0000, test_loss = 0.8064
# # of parameters = 32, train_loss = 0.0000, test_loss = 0.8093
# # of parameters = 33, train_loss = 0.0000, test_loss = 0.8079
# # of parameters = 34, train_loss = 0.0000, test_loss = 0.8077
# # of parameters = 35, train_loss = 0.0000, test_loss = 0.8042
# # of parameters = 36, train_loss = 0.0000, test_loss = 0.8031
# # of parameters = 37, train_loss = 0.0000, test_loss = 0.8029
# # of parameters = 38, train_loss = 0.0000, test_loss = 0.8025
# # of parameters = 39, train_loss = 0.0000, test_loss = 0.7950
# # of parameters = 40, train_loss = 0.0000, test_loss = 0.7896
# # of parameters = 41, train_loss = 0.0000, test_loss = 0.7813
# # of parameters = 42, train_loss = 0.0000, test_loss = 0.7716
# # of parameters = 43, train_loss = 0.0000, test_loss = 0.7746
# # of parameters = 44, train_loss = 0.0000, test_loss = 0.7776
# # of parameters = 45, train_loss = 0.0000, test_loss = 0.7644
# # of parameters = 46, train_loss = 0.0000, test_loss = 0.7647
# # of parameters = 47, train_loss = 0.0000, test_loss = 0.7561
# # of parameters = 48, train_loss = 0.0000, test_loss = 0.7534
# # of parameters = 49, train_loss = 0.0000, test_loss = 0.7534
# # of parameters = 50, train_loss = 0.0000, test_loss = 0.7499
# # of parameters = 51, train_loss = 0.0000, test_loss = 0.7453
# # of parameters = 52, train_loss = 0.0000, test_loss = 0.7435
# # of parameters = 53, train_loss = 0.0000, test_loss = 0.7427
# # of parameters = 54, train_loss = 0.0000, test_loss = 0.7365
# # of parameters = 55, train_loss = 0.0000, test_loss = 0.7397
# # of parameters = 56, train_loss = 0.0000, test_loss = 0.7398
# # of parameters = 57, train_loss = 0.0000, test_loss = 0.7381
# # of parameters = 58, train_loss = 0.0000, test_loss = 0.7217
# # of parameters = 59, train_loss = 0.0000, test_loss = 0.7221
# # of parameters = 60, train_loss = 0.0000, test_loss = 0.7193
# # of parameters = 61, train_loss = 0.0000, test_loss = 0.7209
# # of parameters = 62, train_loss = 0.0000, test_loss = 0.7201
# # of parameters = 63, train_loss = 0.0000, test_loss = 0.7178
# # of parameters = 64, train_loss = 0.0000, test_loss = 0.7170
# # of parameters = 65, train_loss = 0.0000, test_loss = 0.7166
# # of parameters = 66, train_loss = 0.0000, test_loss = 0.7161
# # of parameters = 67, train_loss = 0.0000, test_loss = 0.7162
# # of parameters = 68, train_loss = 0.0000, test_loss = 0.7163
# # of parameters = 69, train_loss = 0.0000, test_loss = 0.7163
# # of parameters = 70, train_loss = 0.0000, test_loss = 0.7162
# # of parameters = 71, train_loss = 0.0000, test_loss = 0.7154
# # of parameters = 72, train_loss = 0.0000, test_loss = 0.7148
# # of parameters = 73, train_loss = 0.0000, test_loss = 0.7167
# # of parameters = 74, train_loss = 0.0000, test_loss = 0.7168
# # of parameters = 75, train_loss = 0.0000, test_loss = 0.7165
# # of parameters = 76, train_loss = 0.0000, test_loss = 0.7110
# # of parameters = 77, train_loss = 0.0000, test_loss = 0.7112
# # of parameters = 78, train_loss = 0.0000, test_loss = 0.7106
# # of parameters = 79, train_loss = 0.0000, test_loss = 0.7102
# # of parameters = 80, train_loss = 0.0000, test_loss = 0.7096
# # of parameters = 81, train_loss = 0.0000, test_loss = 0.7091
# # of parameters = 82, train_loss = 0.0000, test_loss = 0.7097
# # of parameters = 83, train_loss = 0.0000, test_loss = 0.7086
# # of parameters = 84, train_loss = 0.0000, test_loss = 0.7076
# # of parameters = 85, train_loss = 0.0000, test_loss = 0.7075
# # of parameters = 86, train_loss = 0.0000, test_loss = 0.7076
# # of parameters = 87, train_loss = 0.0000, test_loss = 0.7076
# # of parameters = 88, train_loss = 0.0000, test_loss = 0.7082
# # of parameters = 89, train_loss = 0.0000, test_loss = 0.7072
# # of parameters = 90, train_loss = 0.0000, test_loss = 0.7047
# # of parameters = 91, train_loss = 0.0000, test_loss = 0.7043
# # of parameters = 92, train_loss = 0.0000, test_loss = 0.7054
# # of parameters = 93, train_loss = 0.0000, test_loss = 0.7053
# # of parameters = 94, train_loss = 0.0000, test_loss = 0.6999
# # of parameters = 95, train_loss = 0.0000, test_loss = 0.6998
# # of parameters = 96, train_loss = 0.0000, test_loss = 0.6987
# # of parameters = 97, train_loss = 0.0000, test_loss = 0.6987
# # of parameters = 98, train_loss = 0.0000, test_loss = 0.6984
# # of parameters = 99, train_loss = 0.0000, test_loss = 0.6983
# # of parameters = 100, train_loss = 0.0000, test_loss = 0.6982
# # of parameters = 101, train_loss = 0.0000, test_loss = 0.6982
# # of parameters = 102, train_loss = 0.0000, test_loss = 0.6987
# # of parameters = 103, train_loss = 0.0000, test_loss = 0.6984
# # of parameters = 104, train_loss = 0.0000, test_loss = 0.6983
# # of parameters = 105, train_loss = 0.0000, test_loss = 0.6984
# # of parameters = 106, train_loss = 0.0000, test_loss = 0.6984
# # of parameters = 107, train_loss = 0.0000, test_loss = 0.6957
# # of parameters = 108, train_loss = 0.0000, test_loss = 0.6962
# # of parameters = 109, train_loss = 0.0000, test_loss = 0.6958
# # of parameters = 110, train_loss = 0.0000, test_loss = 0.6975
# # of parameters = 111, train_loss = 0.0000, test_loss = 0.6975
# # of parameters = 112, train_loss = 0.0000, test_loss = 0.6974
# # of parameters = 113, train_loss = 0.0000, test_loss = 0.6979
# # of parameters = 114, train_loss = 0.0000, test_loss = 0.6972
# # of parameters = 115, train_loss = 0.0000, test_loss = 0.6976
# # of parameters = 116, train_loss = 0.0000, test_loss = 0.6978
# # of parameters = 117, train_loss = 0.0000, test_loss = 0.6978
# # of parameters = 118, train_loss = 0.0000, test_loss = 0.6974
# # of parameters = 119, train_loss = 0.0000, test_loss = 0.6980
# # of parameters = 120, train_loss = 0.0000, test_loss = 0.6983
# # of parameters = 121, train_loss = 0.0000, test_loss = 0.6984
# # of parameters = 122, train_loss = 0.0000, test_loss = 0.6989
# # of parameters = 123, train_loss = 0.0000, test_loss = 0.6990
# # of parameters = 124, train_loss = 0.0000, test_loss = 0.6990
# # of parameters = 125, train_loss = 0.0000, test_loss = 0.6985
# # of parameters = 126, train_loss = 0.0000, test_loss = 0.6981
# # of parameters = 127, train_loss = 0.0000, test_loss = 0.6972
# # of parameters = 128, train_loss = 0.0000, test_loss = 0.6970
# # of parameters = 129, train_loss = 0.0000, test_loss = 0.6969
# # of parameters = 130, train_loss = 0.0000, test_loss = 0.6970
# # of parameters = 131, train_loss = 0.0000, test_loss = 0.6980
# # of parameters = 132, train_loss = 0.0000, test_loss = 0.6973
# # of parameters = 133, train_loss = 0.0000, test_loss = 0.6972
# # of parameters = 134, train_loss = 0.0000, test_loss = 0.6964
# # of parameters = 135, train_loss = 0.0000, test_loss = 0.6962
# # of parameters = 136, train_loss = 0.0000, test_loss = 0.6962
# # of parameters = 137, train_loss = 0.0000, test_loss = 0.6960
# # of parameters = 138, train_loss = 0.0000, test_loss = 0.6966
# # of parameters = 139, train_loss = 0.0000, test_loss = 0.6960
# # of parameters = 140, train_loss = 0.0000, test_loss = 0.6956
# # of parameters = 141, train_loss = 0.0000, test_loss = 0.6959
# # of parameters = 142, train_loss = 0.0000, test_loss = 0.6959
# # of parameters = 143, train_loss = 0.0000, test_loss = 0.6953
# # of parameters = 144, train_loss = 0.0000, test_loss = 0.6952
# # of parameters = 145, train_loss = 0.0000, test_loss = 0.6946
# # of parameters = 146, train_loss = 0.0000, test_loss = 0.6936
# # of parameters = 147, train_loss = 0.0000, test_loss = 0.6936
# # of parameters = 148, train_loss = 0.0000, test_loss = 0.6936
# # of parameters = 149, train_loss = 0.0000, test_loss = 0.6941
# # of parameters = 150, train_loss = 0.0000, test_loss = 0.6933
# # of parameters = 151, train_loss = 0.0000, test_loss = 0.6935
# # of parameters = 152, train_loss = 0.0000, test_loss = 0.6937
# # of parameters = 153, train_loss = 0.0000, test_loss = 0.6936
# # of parameters = 154, train_loss = 0.0000, test_loss = 0.6943
# # of parameters = 155, train_loss = 0.0000, test_loss = 0.6942
# # of parameters = 156, train_loss = 0.0000, test_loss = 0.6938
# # of parameters = 157, train_loss = 0.0000, test_loss = 0.6938
# # of parameters = 158, train_loss = 0.0000, test_loss = 0.6939
# # of parameters = 159, train_loss = 0.0000, test_loss = 0.6933
# # of parameters = 160, train_loss = 0.0000, test_loss = 0.6932
# # of parameters = 161, train_loss = 0.0000, test_loss = 0.6932
# # of parameters = 162, train_loss = 0.0000, test_loss = 0.6942
# # of parameters = 163, train_loss = 0.0000, test_loss = 0.6930
# # of parameters = 164, train_loss = 0.0000, test_loss = 0.6920
# # of parameters = 165, train_loss = 0.0000, test_loss = 0.6909
# # of parameters = 166, train_loss = 0.0000, test_loss = 0.6909
# # of parameters = 167, train_loss = 0.0000, test_loss = 0.6909
# # of parameters = 168, train_loss = 0.0000, test_loss = 0.6898
# # of parameters = 169, train_loss = 0.0000, test_loss = 0.6895
# # of parameters = 170, train_loss = 0.0000, test_loss = 0.6896
# # of parameters = 171, train_loss = 0.0000, test_loss = 0.6893
# # of parameters = 172, train_loss = 0.0000, test_loss = 0.6888
# # of parameters = 173, train_loss = 0.0000, test_loss = 0.6890
# # of parameters = 174, train_loss = 0.0000, test_loss = 0.6887
# # of parameters = 175, train_loss = 0.0000, test_loss = 0.6882
# # of parameters = 176, train_loss = 0.0000, test_loss = 0.6868
# # of parameters = 177, train_loss = 0.0000, test_loss = 0.6865
# # of parameters = 178, train_loss = 0.0000, test_loss = 0.6868
# # of parameters = 179, train_loss = 0.0000, test_loss = 0.6868
# # of parameters = 180, train_loss = 0.0000, test_loss = 0.6880
# # of parameters = 181, train_loss = 0.0000, test_loss = 0.6872
# # of parameters = 182, train_loss = 0.0000, test_loss = 0.6872
# # of parameters = 183, train_loss = 0.0000, test_loss = 0.6867
# # of parameters = 184, train_loss = 0.0000, test_loss = 0.6873
# # of parameters = 185, train_loss = 0.0000, test_loss = 0.6873
# # of parameters = 186, train_loss = 0.0000, test_loss = 0.6873
# # of parameters = 187, train_loss = 0.0000, test_loss = 0.6875
# # of parameters = 188, train_loss = 0.0000, test_loss = 0.6877
# # of parameters = 189, train_loss = 0.0000, test_loss = 0.6884
# # of parameters = 190, train_loss = 0.0000, test_loss = 0.6884
# # of parameters = 191, train_loss = 0.0000, test_loss = 0.6884
# # of parameters = 192, train_loss = 0.0000, test_loss = 0.6887
# # of parameters = 193, train_loss = 0.0000, test_loss = 0.6888
# # of parameters = 194, train_loss = 0.0000, test_loss = 0.6888
# # of parameters = 195, train_loss = 0.0000, test_loss = 0.6880
# # of parameters = 196, train_loss = 0.0000, test_loss = 0.6873
# # of parameters = 197, train_loss = 0.0000, test_loss = 0.6872
# # of parameters = 198, train_loss = 0.0000, test_loss = 0.6866
# # of parameters = 199, train_loss = 0.0000, test_loss = 0.6865
# # of parameters = 200, train_loss = 0.0000, test_loss = 0.6865

# %%
y_lower, y_upper = -3, 3

# We plot the objective function, fitted function and training data
degree = 1
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 10
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 100
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 200
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)

# %%
plot_double_descent(output_df, n_samples)

# %% [markdown]
# \

# %% [markdown]
# # **2. Polynomial Features using OLS**

# %% [markdown]
# We will now perform the same approximation of the objective functions from standard polynomial regression, instead of using Legendre polynomials.

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

def fit_polynomial_regression(degree, X_train, y_train, X_test):
  '''
  Function to perform polynomial regression using standard polynomial features.

  Example of use:
  X_train_poly, y_train_pred, y_test_pred = fit_polynomial_regression(3, X_train, y_train, X_test)

  '''
  # Reshape input data to ensure 2D format
  X_train = X_train.reshape(-1, 1)
  X_test = X_test.reshape(-1, 1)

  # Create polynomial features using PolynomialFeatures()
  poly = PolynomialFeatures(degree=degree)
  X_train_poly = poly.fit_transform(X_train)
  X_test_poly = poly.transform(X_test)

  # Fit the linear regression model using LinearRegression()
  model = LinearRegression()
  model.fit(X_train_poly, y_train)

  # Predict values for training and test sets
  y_train_pred = model.predict(X_train_poly)
  y_test_pred = model.predict(X_test_poly)

  return X_train_poly, y_train_pred, y_test_pred

# %% [markdown]
# For this purpose, we use the functions (**PolynomialFeatures()**) and (**LinearRegression()**) of sklearn. The first one will generate the polynomial structure to be approximated and the second one will offer the approximation using the OLS method.

# %%
# Here we generate the training data and we plot them together with the objective function
lower_bound, higher_bound = -1.0, 1.0
X_test = np.linspace(lower_bound, higher_bound, num=1000)
y_test = objective_function1(X_test)
n_samples = 10
X_train, y_train = generate_uniformly_distributed_training_data(lower_bound, higher_bound, n_samples, objective_function1)
plot_objective_function_and_training_data(X_train, y_train, X_test, y_test)

# %%
output = []

from sklearn.metrics import mean_squared_error

# Number of params we want to use for the approximation (we use [1, 200] params following "arXiv:2303.14151")
degrees = list(range(200000, 200001))

# For each degree in [1, 500] we calculate the fitted function and see how it fits the objective function by using MSE in training and test.
for degree in degrees:
  X_train_poly, y_train_pred, y_test_pred = fit_polynomial_regression(degree, X_train, y_train, X_test)

  # We calculate the MSE for the training and test data
  train_error = mean_squared_error(y_train, y_train_pred)
  test_error = mean_squared_error(y_test, y_test_pred)

  # We print the degree and both the MSE in training and the MSE in test for that approximation
  print(f"# of parameters = {degree}, train_error = {train_error:.4f}, test_error = {test_error:.4f}")

  # We save all the results so we can use them lately
  output.append({"# of parameters": degree, "X_train_poly": X_train_poly, "train_error": train_error, "test_error": test_error, "y_test_pred": y_test_pred})

# We convert the output into a pandas dataframe
output_df = pd.DataFrame(output)
# Out:
# # of parameters = 200000, train_error = 0.0000, test_error = 53859.8441

# %%
y_lower, y_upper = -5, 5

# We plot the objective function, fitted function and training data
degree = 1
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 10
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 100
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 200
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 300
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 400
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 500
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)

# %%
plot_double_descent(output_df, n_samples, "$2x + cos(25x)$", False)

# %% [markdown]
# \

# %% [markdown]
# # **3. Polynomial Features using GD**

# %% [markdown]
# In this case we will perform the standard polynomial approximation using the gradient descent method instead of the OLS method.

# %%
def poly_features(X, degree):
  '''
  Function to generate polynomial features using up to a given degree.

  '''
  X = X.reshape(-1, 1)
  X_poly = np.ones((X.shape[0], 1))

  # Iterate through degrees from 1 to specified degree and append polynomial terms of X to the matrix
  # When X is a 1D input this is the same as using PolynomialFeatures()
  for d in range(1, degree + 1):
      X_poly = np.hstack((X_poly, X**d))

  return X_poly

def forward_pass(X, w, b):
  '''
  Function to compute the forward pass in linear regression using the features (X),
  the weights (w) and the bias (b).

  '''
  return np.dot(X, w) + b

def loss_MSE(y, y_pred):
  '''
  Function to compute Mean Squared Error (MSE) loss.

  '''
  y = y.reshape(-1, 1)
  loss = np.mean((y_pred-y)**2)

  return loss

def derivatives(X, y, y_pred):
  '''
  Function to compute the gradient of loss with respect to weights and bias.

  '''
  y = y.reshape(-1, 1)

  # Compute gradient for bias and weigths following https://www.kaggle.com/code/grayphantom/polynomial-regression-using-gradient-descent
  db = 2 * np.mean(y_pred - y)
  dw = 2 * np.dot(X.T, (y_pred - y)) / X.shape[0]

  return db, dw

def predict(X, weights, bias, degree):
  '''
  Function to make predictions using a trained polynomial regression model.

  '''
  X = poly_features(X, degree)
  # Compute predictions using weights and bias
  return np.dot(X, weights) + bias

# %%
def train(X_train, y_train, X_test, y_test, degree, learning_rate, epochs):
  '''
  Function to train a polynomial regression model of a certain degree (degree) using
  gradient descent with a given learning rate (learning_rate) and number of epochs (epochs).

  '''
  # Polynomial features for train and test data points
  X_new_train = poly_features(X_train, degree)
  X_new_test = poly_features(X_test, degree)

  # Initial weights and bias set to 0
  n = X_new_train.shape[1]
  weights = np.zeros((n,1))
  bias = 0

  # Training loop
  for epoch in range(epochs+1):
    # Forward pass
    y_pred = forward_pass(X_new_train, weights, bias)

    # We calculate the derivatives with respect to w and b (gradient)
    db, dw = derivatives(X_new_train, y_train, y_pred)

    # We need to modify all weights including bias (update weights)
    weights -= learning_rate * dw
    bias -= learning_rate * db

  return bias, weights

# %%
output = []

# Rango de grados [1, 200]
degrees = list(range(1, 201))

for degree in degrees:
  # Entrenar el modelo con las características generadas
  bias, weights = train(X_train, y_train, X_test, y_test, degree, learning_rate = 0.01, epochs = 5000)

  y_train_pred = predict(X_train, weights, bias, degree)
  y_test_pred = predict(X_test, weights, bias, degree)

  # We calculate the MSE for the training and test data
  train_error = mean_squared_error(y_train, y_train_pred)
  test_error = mean_squared_error(y_test, y_test_pred)

  # We print the degree and both the MSE in training and the MSE in test for that approximation
  print(f"# of parameters = {degree}, train_error = {train_error:.4f}, test_error = {test_error:.4f}")

  # We save all the results so we can use them lately
  output.append({"# of parameters": degree, "train_error": train_error, "test_error": test_error, "y_test_pred": y_test_pred})

# Convertir la salida a un dataframe de pandas para análisis posterior
output_df = pd.DataFrame(output)
# Out:
# # of parameters = 1, train_error = 0.3369, test_error = 0.4996
# # of parameters = 2, train_error = 0.3348, test_error = 0.5018
# # of parameters = 3, train_error = 0.2872, test_error = 0.5452
# # of parameters = 4, train_error = 0.2695, test_error = 0.5454
# # of parameters = 5, train_error = 0.2655, test_error = 0.5543
# # of parameters = 6, train_error = 0.2412, test_error = 0.5686
# # of parameters = 7, train_error = 0.2370, test_error = 0.5770
# # of parameters = 8, train_error = 0.2147, test_error = 0.5981
# # of parameters = 9, train_error = 0.2109, test_error = 0.6069
# # of parameters = 10, train_error = 0.1947, test_error = 0.6246
# # of parameters = 11, train_error = 0.1924, test_error = 0.6307
# # of parameters = 12, train_error = 0.1825, test_error = 0.6396
# # of parameters = 13, train_error = 0.1816, test_error = 0.6420
# # of parameters = 14, train_error = 0.1763, test_error = 0.6425
# # of parameters = 15, train_error = 0.1762, test_error = 0.6419
# # of parameters = 16, train_error = 0.1735, test_error = 0.6372
# # of parameters = 17, train_error = 0.1738, test_error = 0.6350
# # of parameters = 18, train_error = 0.1723, test_error = 0.6280
# # of parameters = 19, train_error = 0.1727, test_error = 0.6253
# # of parameters = 20, train_error = 0.1719, test_error = 0.6180
# # of parameters = 21, train_error = 0.1722, test_error = 0.6153
# # of parameters = 22, train_error = 0.1717, test_error = 0.6086
# # of parameters = 23, train_error = 0.1720, test_error = 0.6062
# # of parameters = 24, train_error = 0.1717, test_error = 0.6004
# # of parameters = 25, train_error = 0.1719, test_error = 0.5984
# # of parameters = 26, train_error = 0.1716, test_error = 0.5937
# # of parameters = 27, train_error = 0.1718, test_error = 0.5920
# # of parameters = 28, train_error = 0.1717, test_error = 0.5881
# # of parameters = 29, train_error = 0.1718, test_error = 0.5867
# # of parameters = 30, train_error = 0.1717, test_error = 0.5836
# # of parameters = 31, train_error = 0.1718, test_error = 0.5824
# # of parameters = 32, train_error = 0.1717, test_error = 0.5799
# # of parameters = 33, train_error = 0.1718, test_error = 0.5789
# # of parameters = 34, train_error = 0.1717, test_error = 0.5770
# # of parameters = 35, train_error = 0.1718, test_error = 0.5761
# # of parameters = 36, train_error = 0.1717, test_error = 0.5746
# # of parameters = 37, train_error = 0.1718, test_error = 0.5738
# # of parameters = 38, train_error = 0.1717, test_error = 0.5727
# # of parameters = 39, train_error = 0.1718, test_error = 0.5720
# # of parameters = 40, train_error = 0.1717, test_error = 0.5711
# # of parameters = 41, train_error = 0.1718, test_error = 0.5705
# # of parameters = 42, train_error = 0.1718, test_error = 0.5699
# # of parameters = 43, train_error = 0.1718, test_error = 0.5694
# # of parameters = 44, train_error = 0.1718, test_error = 0.5689
# # of parameters = 45, train_error = 0.1718, test_error = 0.5685
# # of parameters = 46, train_error = 0.1718, test_error = 0.5682
# # of parameters = 47, train_error = 0.1718, test_error = 0.5678
# # of parameters = 48, train_error = 0.1718, test_error = 0.5676
# # of parameters = 49, train_error = 0.1718, test_error = 0.5672
# # of parameters = 50, train_error = 0.1718, test_error = 0.5671
# # of parameters = 51, train_error = 0.1718, test_error = 0.5668
# # of parameters = 52, train_error = 0.1718, test_error = 0.5668
# # of parameters = 53, train_error = 0.1718, test_error = 0.5665
# # of parameters = 54, train_error = 0.1718, test_error = 0.5666
# # of parameters = 55, train_error = 0.1718, test_error = 0.5664
# # of parameters = 56, train_error = 0.1718, test_error = 0.5665
# # of parameters = 57, train_error = 0.1718, test_error = 0.5663
# # of parameters = 58, train_error = 0.1718, test_error = 0.5664
# # of parameters = 59, train_error = 0.1718, test_error = 0.5662
# # of parameters = 60, train_error = 0.1718, test_error = 0.5664
# # of parameters = 61, train_error = 0.1718, test_error = 0.5662
# # of parameters = 62, train_error = 0.1718, test_error = 0.5664
# # of parameters = 63, train_error = 0.1719, test_error = 0.5663
# # of parameters = 64, train_error = 0.1719, test_error = 0.5665
# # of parameters = 65, train_error = 0.1719, test_error = 0.5665
# # of parameters = 66, train_error = 0.1719, test_error = 0.5667
# # of parameters = 67, train_error = 0.1719, test_error = 0.5666
# # of parameters = 68, train_error = 0.1719, test_error = 0.5669
# # of parameters = 69, train_error = 0.1719, test_error = 0.5668
# # of parameters = 70, train_error = 0.1719, test_error = 0.5671
# # of parameters = 71, train_error = 0.1719, test_error = 0.5670
# # of parameters = 72, train_error = 0.1719, test_error = 0.5673
# # of parameters = 73, train_error = 0.1719, test_error = 0.5673
# # of parameters = 74, train_error = 0.1719, test_error = 0.5675
# # of parameters = 75, train_error = 0.1719, test_error = 0.5675
# # of parameters = 76, train_error = 0.1719, test_error = 0.5678
# # of parameters = 77, train_error = 0.1719, test_error = 0.5678
# # of parameters = 78, train_error = 0.1719, test_error = 0.5681
# # of parameters = 79, train_error = 0.1719, test_error = 0.5681
# # of parameters = 80, train_error = 0.1719, test_error = 0.5684
# # of parameters = 81, train_error = 0.1719, test_error = 0.5684
# # of parameters = 82, train_error = 0.1719, test_error = 0.5686
# # of parameters = 83, train_error = 0.1719, test_error = 0.5687
# # of parameters = 84, train_error = 0.1719, test_error = 0.5690
# # of parameters = 85, train_error = 0.1719, test_error = 0.5690
# # of parameters = 86, train_error = 0.1719, test_error = 0.5693
# # of parameters = 87, train_error = 0.1719, test_error = 0.5693
# # of parameters = 88, train_error = 0.1719, test_error = 0.5696
# # of parameters = 89, train_error = 0.1719, test_error = 0.5696
# # of parameters = 90, train_error = 0.1719, test_error = 0.5699
# # of parameters = 91, train_error = 0.1719, test_error = 0.5700
# # of parameters = 92, train_error = 0.1719, test_error = 0.5702
# # of parameters = 93, train_error = 0.1719, test_error = 0.5703
# # of parameters = 94, train_error = 0.1719, test_error = 0.5705
# # of parameters = 95, train_error = 0.1719, test_error = 0.5706
# # of parameters = 96, train_error = 0.1719, test_error = 0.5709
# # of parameters = 97, train_error = 0.1719, test_error = 0.5709
# # of parameters = 98, train_error = 0.1719, test_error = 0.5712
# # of parameters = 99, train_error = 0.1719, test_error = 0.5713
# # of parameters = 100, train_error = 0.1719, test_error = 0.5715
# # of parameters = 101, train_error = 0.1719, test_error = 0.5716
# # of parameters = 102, train_error = 0.1719, test_error = 0.5718
# # of parameters = 103, train_error = 0.1719, test_error = 0.5719
# # of parameters = 104, train_error = 0.1719, test_error = 0.5721
# # of parameters = 105, train_error = 0.1719, test_error = 0.5722
# # of parameters = 106, train_error = 0.1719, test_error = 0.5724
# # of parameters = 107, train_error = 0.1719, test_error = 0.5725
# # of parameters = 108, train_error = 0.1719, test_error = 0.5727
# # of parameters = 109, train_error = 0.1719, test_error = 0.5728
# # of parameters = 110, train_error = 0.1719, test_error = 0.5730
# # of parameters = 111, train_error = 0.1719, test_error = 0.5731
# # of parameters = 112, train_error = 0.1719, test_error = 0.5733
# # of parameters = 113, train_error = 0.1719, test_error = 0.5734
# # of parameters = 114, train_error = 0.1719, test_error = 0.5736
# # of parameters = 115, train_error = 0.1719, test_error = 0.5737
# # of parameters = 116, train_error = 0.1719, test_error = 0.5739
# # of parameters = 117, train_error = 0.1719, test_error = 0.5740
# # of parameters = 118, train_error = 0.1719, test_error = 0.5742
# # of parameters = 119, train_error = 0.1719, test_error = 0.5743
# # of parameters = 120, train_error = 0.1719, test_error = 0.5745
# # of parameters = 121, train_error = 0.1719, test_error = 0.5745
# # of parameters = 122, train_error = 0.1719, test_error = 0.5747
# # of parameters = 123, train_error = 0.1719, test_error = 0.5748
# # of parameters = 124, train_error = 0.1719, test_error = 0.5750
# # of parameters = 125, train_error = 0.1719, test_error = 0.5751
# # of parameters = 126, train_error = 0.1719, test_error = 0.5752
# # of parameters = 127, train_error = 0.1719, test_error = 0.5753
# # of parameters = 128, train_error = 0.1719, test_error = 0.5755
# # of parameters = 129, train_error = 0.1719, test_error = 0.5756
# # of parameters = 130, train_error = 0.1719, test_error = 0.5757
# # of parameters = 131, train_error = 0.1719, test_error = 0.5758
# # of parameters = 132, train_error = 0.1719, test_error = 0.5760
# # of parameters = 133, train_error = 0.1719, test_error = 0.5760
# # of parameters = 134, train_error = 0.1719, test_error = 0.5762
# # of parameters = 135, train_error = 0.1719, test_error = 0.5763
# # of parameters = 136, train_error = 0.1719, test_error = 0.5764
# # of parameters = 137, train_error = 0.1719, test_error = 0.5765
# # of parameters = 138, train_error = 0.1719, test_error = 0.5766
# # of parameters = 139, train_error = 0.1719, test_error = 0.5767
# # of parameters = 140, train_error = 0.1719, test_error = 0.5768
# # of parameters = 141, train_error = 0.1719, test_error = 0.5769
# # of parameters = 142, train_error = 0.1719, test_error = 0.5770
# # of parameters = 143, train_error = 0.1719, test_error = 0.5771
# # of parameters = 144, train_error = 0.1719, test_error = 0.5772
# # of parameters = 145, train_error = 0.1719, test_error = 0.5773
# # of parameters = 146, train_error = 0.1719, test_error = 0.5774
# # of parameters = 147, train_error = 0.1719, test_error = 0.5775
# # of parameters = 148, train_error = 0.1719, test_error = 0.5776
# # of parameters = 149, train_error = 0.1719, test_error = 0.5777
# # of parameters = 150, train_error = 0.1719, test_error = 0.5778
# # of parameters = 151, train_error = 0.1719, test_error = 0.5779
# # of parameters = 152, train_error = 0.1719, test_error = 0.5780
# # of parameters = 153, train_error = 0.1719, test_error = 0.5780
# # of parameters = 154, train_error = 0.1719, test_error = 0.5781
# # of parameters = 155, train_error = 0.1719, test_error = 0.5782
# # of parameters = 156, train_error = 0.1719, test_error = 0.5783
# # of parameters = 157, train_error = 0.1719, test_error = 0.5783
# # of parameters = 158, train_error = 0.1719, test_error = 0.5784
# # of parameters = 159, train_error = 0.1719, test_error = 0.5785
# # of parameters = 160, train_error = 0.1719, test_error = 0.5786
# # of parameters = 161, train_error = 0.1719, test_error = 0.5787
# # of parameters = 162, train_error = 0.1719, test_error = 0.5787
# # of parameters = 163, train_error = 0.1719, test_error = 0.5788
# # of parameters = 164, train_error = 0.1719, test_error = 0.5789
# # of parameters = 165, train_error = 0.1719, test_error = 0.5789
# # of parameters = 166, train_error = 0.1719, test_error = 0.5790
# # of parameters = 167, train_error = 0.1719, test_error = 0.5791
# # of parameters = 168, train_error = 0.1719, test_error = 0.5792
# # of parameters = 169, train_error = 0.1719, test_error = 0.5792
# # of parameters = 170, train_error = 0.1719, test_error = 0.5793
# # of parameters = 171, train_error = 0.1719, test_error = 0.5793
# # of parameters = 172, train_error = 0.1719, test_error = 0.5794
# # of parameters = 173, train_error = 0.1719, test_error = 0.5794
# # of parameters = 174, train_error = 0.1719, test_error = 0.5795
# # of parameters = 175, train_error = 0.1719, test_error = 0.5796
# # of parameters = 176, train_error = 0.1719, test_error = 0.5796
# # of parameters = 177, train_error = 0.1719, test_error = 0.5797
# # of parameters = 178, train_error = 0.1719, test_error = 0.5797
# # of parameters = 179, train_error = 0.1719, test_error = 0.5798
# # of parameters = 180, train_error = 0.1719, test_error = 0.5798
# # of parameters = 181, train_error = 0.1719, test_error = 0.5799
# # of parameters = 182, train_error = 0.1719, test_error = 0.5799
# # of parameters = 183, train_error = 0.1719, test_error = 0.5800
# # of parameters = 184, train_error = 0.1719, test_error = 0.5800
# # of parameters = 185, train_error = 0.1719, test_error = 0.5801
# # of parameters = 186, train_error = 0.1719, test_error = 0.5801
# # of parameters = 187, train_error = 0.1719, test_error = 0.5802
# # of parameters = 188, train_error = 0.1719, test_error = 0.5802
# # of parameters = 189, train_error = 0.1719, test_error = 0.5803
# # of parameters = 190, train_error = 0.1719, test_error = 0.5803
# # of parameters = 191, train_error = 0.1719, test_error = 0.5803
# # of parameters = 192, train_error = 0.1719, test_error = 0.5804
# # of parameters = 193, train_error = 0.1719, test_error = 0.5804
# # of parameters = 194, train_error = 0.1719, test_error = 0.5805
# # of parameters = 195, train_error = 0.1719, test_error = 0.5805
# # of parameters = 196, train_error = 0.1719, test_error = 0.5806
# # of parameters = 197, train_error = 0.1719, test_error = 0.5806
# # of parameters = 198, train_error = 0.1719, test_error = 0.5806
# # of parameters = 199, train_error = 0.1719, test_error = 0.5807
# # of parameters = 200, train_error = 0.1719, test_error = 0.5807

# %%
y_lower, y_upper = -3, 3

# We plot the objective function, fitted function and training data
degree = 1
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'].flatten(), output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 10
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'].flatten(), output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 100
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'].flatten(), output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 200
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'].flatten(), output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)

# %%
plot_double_descent(output_df, n_samples, "$2x + cos(25x)$", False, 0)

# %% [markdown]
#  \

# %% [markdown]
# # **3. Polynomial Features using SGDRegressor**

# %% [markdown]
# Finally, we use the **"SGDRegressor"** model to perform the approximation of the objective function.

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

def train_with_sgd(X_train, y_train, X_test, y_test, degree, learning_rate, epochs):
    '''
    Function to train a polynomial regression model of a certain degree (degree) using
    stochastic gradient descent (SGD) with a given learning rate (learning_rate) and
    number of epochs (epochs).

    '''

    # Reshape training and testing features to be column vectors
    X_train = X_train.reshape(-1, 1)
    X_test = X_test.reshape(-1, 1)

    # Convert target values to 1D arrays
    y_train = y_train.ravel()
    y_test = y_test.ravel()

    model = make_pipeline(
        # Generate polynomial features up to the given degree
        PolynomialFeatures(degree),
        # Normalize features to improve convergence speed
        StandardScaler(),
        SGDRegressor(
            loss = 'squared_error',  # Use squared error loss function (same as MSE)
            penalty = None,  # No regularization term
            alpha = 0.0,  # No weight decay applied
            l1_ratio = 0.0,  # Not using L1 regularization
            fit_intercept = True,  # Include the bias term in the model
            max_iter = epochs,  # Number of passes over the training data
            tol = None,  # Disable early stopping
            shuffle = False,  # Do not shuffle data between iterations
            random_state = 42,  # Set random seed for reproducibility
            learning_rate = 'constant',  # Keep a fixed learning rate
            eta0 = learning_rate  # Initial learning rate used in gradient updates
        )
    )

    # Train and fit the model using stochastic gradient descent
    model.fit(X_train, y_train)

    # Generate predictions for both training and testing datasets
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)

    return model, y_pred_train, y_pred_test

# %%
output = []

from sklearn.metrics import mean_squared_error

# Rango de grados [1, 200]
degrees = list(range(1, 201))

# Suponiendo que X_train, y_train, X_test, y_test ya están definidos
for degree in degrees:
  # Entrenar el modelo con las características generadas
  model, y_train_pred, y_test_pred = train_with_sgd(X_train, y_train, X_test, y_test, degree, learning_rate = 0.0001, epochs = 1000)

  # We calculate the MSE for the training and test data
  train_error = mean_squared_error(y_train, y_train_pred)
  test_error = mean_squared_error(y_test, y_test_pred)

  # We print the degree and both the MSE in training and the MSE in test for that approximation
  print(f"# of parameters = {degree}, train_error = {train_error:.4f}, test_error = {test_error:.4f}")

  # We save all the results so we can use them lately
  output.append({"# of parameters": degree, "train_error": train_error, "test_error": test_error, "y_test_pred": y_test_pred})

# Convertir la salida a un dataframe de pandas para análisis posterior
output_df = pd.DataFrame(output)
# Out:
# # of parameters = 1, train_error = 0.5723, test_error = 0.6602
# # of parameters = 2, train_error = 0.5773, test_error = 0.6717
# # of parameters = 3, train_error = 0.3426, test_error = 0.5799
# # of parameters = 4, train_error = 0.3437, test_error = 0.5855
# # of parameters = 5, train_error = 0.3268, test_error = 0.6340
# # of parameters = 6, train_error = 0.3208, test_error = 0.6358
# # of parameters = 7, train_error = 0.3326, test_error = 0.6939
# # of parameters = 8, train_error = 0.3243, test_error = 0.6944
# # of parameters = 9, train_error = 0.3360, test_error = 0.7447
# # of parameters = 10, train_error = 0.3277, test_error = 0.7443
# # of parameters = 11, train_error = 0.3361, test_error = 0.7859
# # of parameters = 12, train_error = 0.3289, test_error = 0.7842
# # of parameters = 13, train_error = 0.3348, test_error = 0.8184
# # of parameters = 14, train_error = 0.3291, test_error = 0.8154
# # of parameters = 15, train_error = 0.3335, test_error = 0.8436
# # of parameters = 16, train_error = 0.3292, test_error = 0.8395
# # of parameters = 17, train_error = 0.3326, test_error = 0.8629
# # of parameters = 18, train_error = 0.3296, test_error = 0.8579
# # of parameters = 19, train_error = 0.3323, test_error = 0.8773
# # of parameters = 20, train_error = 0.3302, test_error = 0.8718
# # of parameters = 21, train_error = 0.3323, test_error = 0.8882
# # of parameters = 22, train_error = 0.3309, test_error = 0.8826
# # of parameters = 23, train_error = 0.3325, test_error = 0.8965
# # of parameters = 24, train_error = 0.3315, test_error = 0.8910
# # of parameters = 25, train_error = 0.3327, test_error = 0.9030
# # of parameters = 26, train_error = 0.3321, test_error = 0.8979
# # of parameters = 27, train_error = 0.3330, test_error = 0.9083
# # of parameters = 28, train_error = 0.3325, test_error = 0.9037
# # of parameters = 29, train_error = 0.3331, test_error = 0.9128
# # of parameters = 30, train_error = 0.3328, test_error = 0.9088
# # of parameters = 31, train_error = 0.3332, test_error = 0.9169
# # of parameters = 32, train_error = 0.3329, test_error = 0.9135
# # of parameters = 33, train_error = 0.3332, test_error = 0.9207
# # of parameters = 34, train_error = 0.3330, test_error = 0.9179
# # of parameters = 35, train_error = 0.3332, test_error = 0.9244
# # of parameters = 36, train_error = 0.3331, test_error = 0.9220
# # of parameters = 37, train_error = 0.3332, test_error = 0.9279
# # of parameters = 38, train_error = 0.3331, test_error = 0.9261
# # of parameters = 39, train_error = 0.3331, test_error = 0.9314
# # of parameters = 40, train_error = 0.3330, test_error = 0.9299
# # of parameters = 41, train_error = 0.3330, test_error = 0.9348
# # of parameters = 42, train_error = 0.3330, test_error = 0.9337
# # of parameters = 43, train_error = 0.3329, test_error = 0.9381
# # of parameters = 44, train_error = 0.3329, test_error = 0.9373
# # of parameters = 45, train_error = 0.3329, test_error = 0.9413
# # of parameters = 46, train_error = 0.3328, test_error = 0.9408
# # of parameters = 47, train_error = 0.3328, test_error = 0.9444
# # of parameters = 48, train_error = 0.3328, test_error = 0.9442
# # of parameters = 49, train_error = 0.3327, test_error = 0.9474
# # of parameters = 50, train_error = 0.3327, test_error = 0.9474
# # of parameters = 51, train_error = 0.3327, test_error = 0.9503
# # of parameters = 52, train_error = 0.3327, test_error = 0.9504
# # of parameters = 53, train_error = 0.3326, test_error = 0.9530
# # of parameters = 54, train_error = 0.3326, test_error = 0.9533
# # of parameters = 55, train_error = 0.3326, test_error = 0.9556
# # of parameters = 56, train_error = 0.3326, test_error = 0.9560
# # of parameters = 57, train_error = 0.3325, test_error = 0.9581
# # of parameters = 58, train_error = 0.3325, test_error = 0.9586
# # of parameters = 59, train_error = 0.3325, test_error = 0.9605
# # of parameters = 60, train_error = 0.3325, test_error = 0.9610
# # of parameters = 61, train_error = 0.3325, test_error = 0.9627
# # of parameters = 62, train_error = 0.3325, test_error = 0.9633
# # of parameters = 63, train_error = 0.3324, test_error = 0.9648
# # of parameters = 64, train_error = 0.3324, test_error = 0.9654
# # of parameters = 65, train_error = 0.3324, test_error = 0.9667
# # of parameters = 66, train_error = 0.3324, test_error = 0.9674
# # of parameters = 67, train_error = 0.3324, test_error = 0.9685
# # of parameters = 68, train_error = 0.3324, test_error = 0.9693
# # of parameters = 69, train_error = 0.3324, test_error = 0.9702
# # of parameters = 70, train_error = 0.3324, test_error = 0.9710
# # of parameters = 71, train_error = 0.3323, test_error = 0.9718
# # of parameters = 72, train_error = 0.3323, test_error = 0.9726
# # of parameters = 73, train_error = 0.3323, test_error = 0.9733
# # of parameters = 74, train_error = 0.3323, test_error = 0.9741
# # of parameters = 75, train_error = 0.3323, test_error = 0.9747
# # of parameters = 76, train_error = 0.3323, test_error = 0.9755
# # of parameters = 77, train_error = 0.3323, test_error = 0.9759
# # of parameters = 78, train_error = 0.3323, test_error = 0.9768
# # of parameters = 79, train_error = 0.3323, test_error = 0.9771
# # of parameters = 80, train_error = 0.3323, test_error = 0.9779
# # of parameters = 81, train_error = 0.3323, test_error = 0.9782
# # of parameters = 82, train_error = 0.3323, test_error = 0.9790
# # of parameters = 83, train_error = 0.3323, test_error = 0.9792
# # of parameters = 84, train_error = 0.3323, test_error = 0.9800
# # of parameters = 85, train_error = 0.3323, test_error = 0.9802
# # of parameters = 86, train_error = 0.3323, test_error = 0.9810
# # of parameters = 87, train_error = 0.3323, test_error = 0.9810
# # of parameters = 88, train_error = 0.3323, test_error = 0.9818
# # of parameters = 89, train_error = 0.3323, test_error = 0.9818
# # of parameters = 90, train_error = 0.3323, test_error = 0.9826
# # of parameters = 91, train_error = 0.3322, test_error = 0.9825
# # of parameters = 92, train_error = 0.3322, test_error = 0.9833
# # of parameters = 93, train_error = 0.3322, test_error = 0.9832
# # of parameters = 94, train_error = 0.3322, test_error = 0.9840
# # of parameters = 95, train_error = 0.3322, test_error = 0.9838
# # of parameters = 96, train_error = 0.3322, test_error = 0.9846
# # of parameters = 97, train_error = 0.3322, test_error = 0.9843
# # of parameters = 98, train_error = 0.3322, test_error = 0.9851
# # of parameters = 99, train_error = 0.3322, test_error = 0.9848
# # of parameters = 100, train_error = 0.3322, test_error = 0.9856
# # of parameters = 101, train_error = 0.3322, test_error = 0.9853
# # of parameters = 102, train_error = 0.3322, test_error = 0.9861
# # of parameters = 103, train_error = 0.3322, test_error = 0.9857
# # of parameters = 104, train_error = 0.3322, test_error = 0.9865
# # of parameters = 105, train_error = 0.3322, test_error = 0.9861
# # of parameters = 106, train_error = 0.3322, test_error = 0.9869
# # of parameters = 107, train_error = 0.3322, test_error = 0.9865
# # of parameters = 108, train_error = 0.3322, test_error = 0.9872
# # of parameters = 109, train_error = 0.3322, test_error = 0.9868
# # of parameters = 110, train_error = 0.3322, test_error = 0.9876
# # of parameters = 111, train_error = 0.3322, test_error = 0.9870
# # of parameters = 112, train_error = 0.3322, test_error = 0.9878
# # of parameters = 113, train_error = 0.3322, test_error = 0.9873
# # of parameters = 114, train_error = 0.3322, test_error = 0.9881
# # of parameters = 115, train_error = 0.3322, test_error = 0.9875
# # of parameters = 116, train_error = 0.3322, test_error = 0.9883
# # of parameters = 117, train_error = 0.3322, test_error = 0.9877
# # of parameters = 118, train_error = 0.3322, test_error = 0.9885
# # of parameters = 119, train_error = 0.3322, test_error = 0.9879
# # of parameters = 120, train_error = 0.3322, test_error = 0.9887
# # of parameters = 121, train_error = 0.3322, test_error = 0.9881
# # of parameters = 122, train_error = 0.3322, test_error = 0.9889
# # of parameters = 123, train_error = 0.3322, test_error = 0.9882
# # of parameters = 124, train_error = 0.3322, test_error = 0.9890
# # of parameters = 125, train_error = 0.3322, test_error = 0.9883
# # of parameters = 126, train_error = 0.3322, test_error = 0.9892
# # of parameters = 127, train_error = 0.3322, test_error = 0.9884
# # of parameters = 128, train_error = 0.3322, test_error = 0.9893
# # of parameters = 129, train_error = 0.3322, test_error = 0.9885
# # of parameters = 130, train_error = 0.3322, test_error = 0.9894
# # of parameters = 131, train_error = 0.3322, test_error = 0.9886
# # of parameters = 132, train_error = 0.3322, test_error = 0.9895
# # of parameters = 133, train_error = 0.3322, test_error = 0.9887
# # of parameters = 134, train_error = 0.3322, test_error = 0.9895
# # of parameters = 135, train_error = 0.3322, test_error = 0.9887
# # of parameters = 136, train_error = 0.3322, test_error = 0.9896
# # of parameters = 137, train_error = 0.3322, test_error = 0.9888
# # of parameters = 138, train_error = 0.3322, test_error = 0.9897
# # of parameters = 139, train_error = 0.3322, test_error = 0.9888
# # of parameters = 140, train_error = 0.3322, test_error = 0.9897
# # of parameters = 141, train_error = 0.3322, test_error = 0.9888
# # of parameters = 142, train_error = 0.3322, test_error = 0.9897
# # of parameters = 143, train_error = 0.3322, test_error = 0.9889
# # of parameters = 144, train_error = 0.3322, test_error = 0.9898
# # of parameters = 145, train_error = 0.3322, test_error = 0.9889
# # of parameters = 146, train_error = 0.3322, test_error = 0.9898
# # of parameters = 147, train_error = 0.3322, test_error = 0.9889
# # of parameters = 148, train_error = 0.3322, test_error = 0.9899
# # of parameters = 149, train_error = 0.3322, test_error = 0.9889
# # of parameters = 150, train_error = 0.3322, test_error = 0.9899
# # of parameters = 151, train_error = 0.3322, test_error = 0.9889
# # of parameters = 152, train_error = 0.3322, test_error = 0.9899
# # of parameters = 153, train_error = 0.3322, test_error = 0.9889
# # of parameters = 154, train_error = 0.3322, test_error = 0.9899
# # of parameters = 155, train_error = 0.3322, test_error = 0.9889
# # of parameters = 156, train_error = 0.3322, test_error = 0.9900
# # of parameters = 157, train_error = 0.3322, test_error = 0.9889
# # of parameters = 158, train_error = 0.3322, test_error = 0.9900
# # of parameters = 159, train_error = 0.3322, test_error = 0.9890
# # of parameters = 160, train_error = 0.3322, test_error = 0.9900
# # of parameters = 161, train_error = 0.3322, test_error = 0.9890
# # of parameters = 162, train_error = 0.3322, test_error = 0.9901
# # of parameters = 163, train_error = 0.3322, test_error = 0.9890
# # of parameters = 164, train_error = 0.3322, test_error = 0.9901
# # of parameters = 165, train_error = 0.3322, test_error = 0.9890
# # of parameters = 166, train_error = 0.3322, test_error = 0.9902
# # of parameters = 167, train_error = 0.3322, test_error = 0.9890
# # of parameters = 168, train_error = 0.3322, test_error = 0.9902
# # of parameters = 169, train_error = 0.3322, test_error = 0.9891
# # of parameters = 170, train_error = 0.3322, test_error = 0.9903
# # of parameters = 171, train_error = 0.3322, test_error = 0.9891
# # of parameters = 172, train_error = 0.3322, test_error = 0.9904
# # of parameters = 173, train_error = 0.3322, test_error = 0.9892
# # of parameters = 174, train_error = 0.3322, test_error = 0.9905
# # of parameters = 175, train_error = 0.3322, test_error = 0.9893
# # of parameters = 176, train_error = 0.3322, test_error = 0.9906
# # of parameters = 177, train_error = 0.3322, test_error = 0.9893
# # of parameters = 178, train_error = 0.3322, test_error = 0.9907
# # of parameters = 179, train_error = 0.3322, test_error = 0.9894
# # of parameters = 180, train_error = 0.3322, test_error = 0.9908
# # of parameters = 181, train_error = 0.3322, test_error = 0.9896
# # of parameters = 182, train_error = 0.3322, test_error = 0.9910
# # of parameters = 183, train_error = 0.3322, test_error = 0.9897
# # of parameters = 184, train_error = 0.3322, test_error = 0.9911
# # of parameters = 185, train_error = 0.3322, test_error = 0.9898
# # of parameters = 186, train_error = 0.3322, test_error = 0.9913
# # of parameters = 187, train_error = 0.3322, test_error = 0.9900
# # of parameters = 188, train_error = 0.3322, test_error = 0.9915
# # of parameters = 189, train_error = 0.3322, test_error = 0.9902
# # of parameters = 190, train_error = 0.3322, test_error = 0.9918
# # of parameters = 191, train_error = 0.3322, test_error = 0.9904
# # of parameters = 192, train_error = 0.3322, test_error = 0.9921
# # of parameters = 193, train_error = 0.3322, test_error = 0.9907
# # of parameters = 194, train_error = 0.3322, test_error = 0.9923
# # of parameters = 195, train_error = 0.3322, test_error = 0.9909
# # of parameters = 196, train_error = 0.3322, test_error = 0.9927
# # of parameters = 197, train_error = 0.3322, test_error = 0.9913
# # of parameters = 198, train_error = 0.3322, test_error = 0.9930
# # of parameters = 199, train_error = 0.3322, test_error = 0.9916
# # of parameters = 200, train_error = 0.3322, test_error = 0.9935

# %%
y_lower, y_upper = -5, 5

# We plot the objective function, fitted function and training data
degree = 1
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 10
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 100
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)
degree = 200
plot_fitting_approximation(X_train, y_train, X_test, y_test, output_df.loc[degree-1, 'y_test_pred'], output_df.loc[degree-1, '# of parameters'], y_lower, y_upper)

# %%
plot_double_descent(output_df, n_samples, "$2x + cos(25x)$", False, 0)
